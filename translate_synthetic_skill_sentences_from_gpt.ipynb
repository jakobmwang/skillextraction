# %%
# install openai library
# !pip install openai -qq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.9/335.9 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00

# %%
# dependencies
import os
import re
import time
import numpy as np
import pandas as pd
import asyncio
import nest_asyncio
from openai import AsyncOpenAI
from google.colab import drive, userdata

# async fix for notebook
nest_asyncio.apply()

# file management
drive.mount('/content/drive')
WORK_DIR = '/content/drive/MyDrive/Projects/skillextraction'

# work dir shortcut function
def work_dir(*args):
    return os.path.join(WORK_DIR, *args)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# openai client for async
client = AsyncOpenAI(api_key=userdata.get('OpenAI'))

# %%
# prompt to completion (api response)
async def get_completion(prompt):
    response = await client.chat.completions.create(
        model='gpt-4o-mini',

        messages=[{'role': 'user', 'content': prompt}]
    )
    return response

# prompts to completions (api responses)
async def get_completions(prompts):
    tasks = [get_completion(prompt) for prompt in prompts]
    return await asyncio.gather(*tasks)

# %%
# prompt template
prompt = 'Please translate the following 10 sentences into Danish, and output them in plain text in the same order as they are given to you, separated by linebreak:'

# %%
# get english sentence dataset
df = pd.read_csv(work_dir('Data', 'dataset.csv'))
print(df.shape)
df.head(3)
# Out:
# (138260, 2)
#                                             sentence  \
# 0  the ideal candidate for this position should b...
# 1  we need an employee who is able to assist our ...
# 2  if you possess good communication skills and h...
#
#                                  skill
# 0  advise customers on sewing patterns
# 1  advise customers on sewing patterns
# 2  advise customers on sewing patterns

# %%
# generate prompt for each skill
prompts = df.groupby('skill')['sentence'].agg('\n'.join).reset_index()
prompts['sentence'] = prompt + '\n\n' + prompts['sentence']

# check example
prompts.shape
prompts.head(3)
# Out:
#                            skill  \
# 0        procurement legislation
# 1  3D body scanning technologies
# 2                    3D lighting
#
#                                             sentence
# 0  Please translate the following 10 sentences in...
# 1  Please translate the following 10 sentences in...
# 2  Please translate the following 10 sentences in...

# %%
# check full prompt example
print(prompts.head(1)['sentence'].values[0])
# Out:
# Please translate the following 10 sentences into Danish, and output them in plain text in the same order as they are given to you, separated by linebreak:
#
# a comprehensive understanding of procurement legislation is essential for this position.
# familiarity and experience with procurement legislation is a must-have for applicants to this position.
# applicants with experience working in fields related to procurement legislation are strongly encouraged to apply.
# to be considered for this role, you must have a strong understanding of procurement legislation and the role it plays in public procurement.
# the ideal candidate for this job will have a deep understanding of procurement legislation and its implications for public procurement.
# the ideal candidate will have a proven track record of working with procurement legislation and policies.
# knowledge of procurement legislation at the national and European levels is crucial to the success of this role.
# minimum qualifications for this role include being able to demonstrate a working knowledge of procurement legislation and adjacent areas of law.
# we're seeking candidates with extensive knowledge of procurement legislation at both national and European levels
# must have a deep understanding of procurement legislation and be able to keep up-to-date with changes.

# %%
# separate in chunks of 100
chunks = np.array_split(prompts, np.arange(100, len(prompts), 100))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#                                           skill  \
# 100                                      German
# 101  Global Maritime Distress and Safety System
# 102                                       Greek
# 103                                      Groovy
# 104                                       Grovo
# ..                                          ...
# 195                                   MarkLogic
# 196                                  Metasploit
# 197                            Microsoft Access
# 198                             Microsoft Visio
# 199                        Microsoft Visual C++
#
#                                               sentence
# 100  Please translate the following 10 sentences in...
# 101  Please translate the following 10 sentences in...
# 102  Please translate the following 10 sentences in...
# 103  Please translate the following 10 sentences in...
# 104  Please translate the following 10 sentences in...
# ..                                                 ...
# 195  Please translate the following 10 sentences in...
# 196  Please translate the following 10 sentences in...
# 197  Please translate the following 10 sentences in...
# 198  Please translate the following 10 sentences in...
# 199  Please translate the following 10 sentences in...
#
# [100 rows x 2 columns]

# %%
# get completions for each chunk
for i, chunk in enumerate(chunks):
    filename = os.path.join(WORK_DIR, 'Translated_data', 'translated_sentences_{}.csv'.format(i))
    if os.path.exists(filename):
        continue
    completions = await get_completions(chunk['sentence'].values)
    completions = [[t for s in c.choices[0].message.content.split('\n') if (t := re.sub(r'^[\W0-9]+', '', s).strip()) != ''] for c in completions]
    chunk['sentence'] = completions
    chunk.explode('sentence')[['skill', 'sentence']].to_csv(filename, index=False)
    time.sleep(50) # avoiding rate limits

# %%
# sanity check
df = pd.read_csv(os.path.join(WORK_DIR, 'Translated_data', 'translated_sentences_{}.csv'.format(i)))
df
# Out:
#                                              conceptUri  \
# 0     http://data.europa.eu/esco/skill/fe77f9ca-7bd2...
# 1     http://data.europa.eu/esco/skill/fe77f9ca-7bd2...
# 2     http://data.europa.eu/esco/skill/fe77f9ca-7bd2...
# 3     http://data.europa.eu/esco/skill/fe77f9ca-7bd2...
# 4     http://data.europa.eu/esco/skill/fe77f9ca-7bd2...
# ...                                                 ...
# 1330  http://data.europa.eu/esco/skill/fff74a70-4f82...
# 1331  http://data.europa.eu/esco/skill/fff74a70-4f82...
# 1332  http://data.europa.eu/esco/skill/fff74a70-4f82...
# 1333  http://data.europa.eu/esco/skill/fff74a70-4f82...
# 1334  http://data.europa.eu/esco/skill/fff74a70-4f82...
#
#                                              completion
# 0     Arbejder du inden for bygge- og anlægsindustri...
# 1     En solid forståelse af de mest anvendte produk...
# 2     Kendskab til de førende produkter, populære mæ...
# 3     Eksperter inden for bygge- og anlægsindustrien...
# 4     En omfattende kendskab til de mest efterspurgt...
# ...                                                 ...
# 1330  erfaring med montering af gelændere og fodbrædder
# 1331     evne til at arbejde med præcision og sikkerhed
# 1332  kendskab til at fastgøre gelændere med kobling...
# 1333  professionel tilgang til at forebygge fald af ...
# 1334  viden om sikkerhedsstandarder for anbringelse ...
#
# [1335 rows x 2 columns]
