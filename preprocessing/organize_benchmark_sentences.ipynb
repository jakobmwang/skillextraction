# %%
import os
import pandas as pd
from transformers import AutoTokenizer
from google.colab import drive, userdata

# file management
drive.mount('/content/drive')
WORK_DIR = '/content/drive/MyDrive/Projects/skillextraction'

# work dir shortcut function
def work_dir(*args):
    return os.path.join(WORK_DIR, *args)
# Out:
# Mounted at /content/drive

# %%
# load skills for filtering benchmark
skills = pd.read_json(work_dir('Data', 'skills.json'), orient='records', lines=True)
skills = skills[skills['group'] == 1] # need only 1 group for label and conceptUri

# check
print(skills.shape)
skills.head(3)
# Out:
# (13813, 3)
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1  http://data.europa.eu/esco/skill/00064735-8fad...
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...
#
#                             sentence  group
# 0               manage musical staff      1
# 1  supervise correctional procedures      1
# 2    apply anti-oppressive practices      1

# %%
# load bench data and assign groups to differentiate
bench = pd.concat([
    pd.read_csv("hf://datasets/jensjorisdecorte/skill-extraction-tech/validation.csv").assign(group=1),
    pd.read_csv("hf://datasets/jensjorisdecorte/skill-extraction-tech/test.csv").assign(group=2),
    pd.read_csv("hf://datasets/jensjorisdecorte/skill-extraction-house/validation.csv").assign(group=3),
    pd.read_csv("hf://datasets/jensjorisdecorte/skill-extraction-house/test.csv").assign(group=4),
    pd.read_csv("hf://datasets/jensjorisdecorte/skill-extraction-techwolf/test.csv").assign(group=5)
], ignore_index=True).reset_index(drop=True)

#check
bench
# Out:
#                                                sentence        span sub_span  \
# 0                               javascript reactjs java  javascript      NaN
# 1                               javascript reactjs java     reactjs      NaN
# 2                               javascript reactjs java        java      NaN
# 3                               javascript reactjs java  javascript      NaN
# 4                               javascript reactjs java     reactjs      NaN
# ...                                                 ...         ...      ...
# 3162  * An ability to inspire, coach and develop you...         NaN      NaN
# 3163  * Role model who consistently delivers amazing...         NaN      NaN
# 3164  * Role model who consistently delivers amazing...         NaN      NaN
# 3165                        * Passion for our products.         NaN      NaN
# 3166                            * A competitive spirit.         NaN      NaN
#
#                                                   label  group
# 0                                            JavaScript      1
# 1                                     LABEL NOT PRESENT      1
# 2                           Java (computer programming)      1
# 3                                            JavaScript      1
# 4                                     LABEL NOT PRESENT      1
# ...                                                 ...    ...
# 3162                                      manage a team      5
# 3163                     manage the customer experience      5
# 3164  show an exemplary leading role in an organisation      5
# 3165                                 show determination      5
# 3166                                 show determination      5
#
# [3167 rows x 5 columns]

# %%
# filter bench by valid labels (exists in skills)
bench['conceptUri'] = bench['label'].map(dict(zip(skills['sentence'], skills['conceptUri'])))
bench = bench[['conceptUri', 'group', 'sentence']]
bench = bench.loc[bench['conceptUri'].notna()]

# check
bench
# Out:
#                                              conceptUri  group  \
# 0     http://data.europa.eu/esco/skill/3cd569a2-4f88...      1
# 2     http://data.europa.eu/esco/skill/19a8293b-8e95...      1
# 3     http://data.europa.eu/esco/skill/3cd569a2-4f88...      1
# 5     http://data.europa.eu/esco/skill/19a8293b-8e95...      1
# 6     http://data.europa.eu/esco/skill/adc6dc11-3376...      1
# ...                                                 ...    ...
# 3162  http://data.europa.eu/esco/skill/cb668e89-6ef5...      5
# 3163  http://data.europa.eu/esco/skill/4b95c7bb-5672...      5
# 3164  http://data.europa.eu/esco/skill/5be1c5fb-3833...      5
# 3165  http://data.europa.eu/esco/skill/19a64e91-bfe3...      5
# 3166  http://data.europa.eu/esco/skill/19a64e91-bfe3...      5
#
#                                                sentence
# 0                               javascript reactjs java
# 2                               javascript reactjs java
# 3                               javascript reactjs java
# 5                               javascript reactjs java
# 6     As a member of our <ORGANIZATION> <ORGANIZATIO...
# ...                                                 ...
# 3162  * An ability to inspire, coach and develop you...
# 3163  * Role model who consistently delivers amazing...
# 3164  * Role model who consistently delivers amazing...
# 3165                        * Passion for our products.
# 3166                            * A competitive spirit.
#
# [2112 rows x 3 columns]

# %%
# load translated bench and shift group numbers and filter
trans_bench = pd.read_json(work_dir('Data', 'translated_bench.json'), orient='records', lines=True)[['conceptUri', 'group', 'sentence']]
trans_bench['group'] += 5
trans_bench = trans_bench.explode('conceptUri').reset_index(drop=True)
trans_bench = trans_bench[trans_bench['conceptUri'].isin(skills['conceptUri'])]
trans_bench = trans_bench.loc[trans_bench['conceptUri'].notna()]

# check
trans_bench
# Out:
#                                              conceptUri  group  \
# 0     http://data.europa.eu/esco/skill/60c78287-22eb...      6
# 1     http://data.europa.eu/esco/skill/113b4428-0a31...      6
# 2     http://data.europa.eu/esco/skill/f7e2eb04-3e50...      6
# 3     http://data.europa.eu/esco/skill/4d85b881-e490...      6
# 4     http://data.europa.eu/esco/skill/d0c6d77e-cb25...      6
# ...                                                 ...    ...
# 2072  http://data.europa.eu/esco/skill/7ff2c668-0e86...     10
# 2073  http://data.europa.eu/esco/skill/91abe492-18be...     10
# 2074  http://data.europa.eu/esco/skill/699e7c26-6502...     10
# 2075  http://data.europa.eu/esco/skill/21c5790c-0930...     10
# 2076  http://data.europa.eu/esco/skill/99c4c69a-025c...     10
#
#                                                sentence
# 0     Evne til at arbejde i store samarbejdsteams fo...
# 1     Evne til at arbejde i store samarbejdsteams fo...
# 2     Avanceret viden om anvendelsesdata og infrastr...
# 3     Avanceret viden om anvendelsesdata og infrastr...
# 4     Avanceret viden om anvendelsesdata og infrastr...
# ...                                                 ...
# 2072  Din rolle vil være at arbejde med både test- o...
# 2073  Din rolle vil være at arbejde med både test- o...
# 2074                           hjælp i deres udvikling.
# 2075  og mindst 2 års erfaring på mellemniveau i for...
# 2076  og mindst 2 års erfaring med at opnå resultate...
#
# [2070 rows x 3 columns]

# %%
# gather benches
total_bench = pd.concat([bench, trans_bench], ignore_index=True)

# check
total_bench
# Out:
#                                              conceptUri  group  \
# 0     http://data.europa.eu/esco/skill/3cd569a2-4f88...      1
# 1     http://data.europa.eu/esco/skill/19a8293b-8e95...      1
# 2     http://data.europa.eu/esco/skill/3cd569a2-4f88...      1
# 3     http://data.europa.eu/esco/skill/19a8293b-8e95...      1
# 4     http://data.europa.eu/esco/skill/adc6dc11-3376...      1
# ...                                                 ...    ...
# 4177  http://data.europa.eu/esco/skill/7ff2c668-0e86...     10
# 4178  http://data.europa.eu/esco/skill/91abe492-18be...     10
# 4179  http://data.europa.eu/esco/skill/699e7c26-6502...     10
# 4180  http://data.europa.eu/esco/skill/21c5790c-0930...     10
# 4181  http://data.europa.eu/esco/skill/99c4c69a-025c...     10
#
#                                                sentence
# 0                               javascript reactjs java
# 1                               javascript reactjs java
# 2                               javascript reactjs java
# 3                               javascript reactjs java
# 4     As a member of our <ORGANIZATION> <ORGANIZATIO...
# ...                                                 ...
# 4177  Din rolle vil være at arbejde med både test- o...
# 4178  Din rolle vil være at arbejde med både test- o...
# 4179                           hjælp i deres udvikling.
# 4180  og mindst 2 års erfaring på mellemniveau i for...
# 4181  og mindst 2 års erfaring med at opnå resultate...
#
# [4182 rows x 3 columns]

# %%
# save to json
total_bench.to_json(work_dir('Data', 'bench.json'), orient='records', lines=True, index=False)

# %%
# sanity check
df = pd.read_json(work_dir('Data', 'bench.json'), orient='records', lines=True)
print(df.shape)
print(df['group'].value_counts().sort_index())
df.head(3)
# Out:
# (4182, 3)
# group
# 1     153
# 2     671
# 3     134
# 4     566
# 5     588
# 6     153
# 7     671
# 8     115
# 9     553
# 10    578
# Name: count, dtype: int64
#                                           conceptUri  group  \
# 0  http://data.europa.eu/esco/skill/3cd569a2-4f88...      1
# 1  http://data.europa.eu/esco/skill/19a8293b-8e95...      1
# 2  http://data.europa.eu/esco/skill/3cd569a2-4f88...      1
#
#                   sentence
# 0  javascript reactjs java
# 1  javascript reactjs java
# 2  javascript reactjs java
