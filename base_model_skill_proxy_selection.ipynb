# %%
import os
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive, userdata

# file management
drive.mount('/content/drive')
WORK_DIR = '/content/drive/MyDrive/Projects/skillextraction'

# work dir shortcut function
def work_dir(*args):
    return os.path.join(WORK_DIR, *args)

# needed for long tables
pd.set_option('display.max_rows', None)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Base Model and Skill Proxy Selection

# %%
# trial
df = pd.read_csv(work_dir('trials', 'base_model.csv')).drop_duplicates(subset=['BASE_MODEL', 'PROXY_SETS', 'epoch'])
df = df.assign(BASE_MODEL=df['BASE_MODEL'].str.replace('sentence-transformers/', ''))

hm = (df.loc[df['epoch'].isin(['desc_en', 'desc_da', 'label_da', 'label_en', 'alt_en_eval', 'alt_da_eval', 'article_eval']),
             ['BASE_MODEL', 'PROXY_SETS', 'epoch', 'cardinality', 'skill_id_cap', 'skill_id_rp5', 'skill_id_mrr']])

# check
print(hm.shape)
print(hm['BASE_MODEL'].value_counts())
hm.sort_values(['skill_id_cap'], ascending=False).reset_index(drop=True)
# Out:
# (96, 7)
# BASE_MODEL
# paraphrase-multilingual-mpnet-base-v2    24
# all-mpnet-base-v2                        24
# labse                                    24
# paraphrase-multilingual-MiniLM-L12-v2    24
# Name: count, dtype: int64
#                                BASE_MODEL    PROXY_SETS         epoch  \
# 0                                   labse   ['desc_en']       desc_da
# 1                                   labse   ['desc_da']       desc_en
# 2   paraphrase-multilingual-mpnet-base-v2   ['desc_da']       desc_en
# 3   paraphrase-multilingual-mpnet-base-v2   ['desc_en']       desc_da
# 4   paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']       desc_en
# 5   paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']       desc_da
# 6                                   labse  ['label_en']      label_da
# 7                                   labse  ['label_da']      label_en
# 8                       all-mpnet-base-v2  ['label_en']   alt_en_eval
# 9   paraphrase-multilingual-mpnet-base-v2  ['label_en']   alt_en_eval
# 10                                  labse  ['label_en']   alt_en_eval
# 11  paraphrase-multilingual-MiniLM-L12-v2  ['label_en']   alt_en_eval
# 12  paraphrase-multilingual-mpnet-base-v2  ['label_da']      label_en
# 13  paraphrase-multilingual-mpnet-base-v2  ['label_en']      label_da
# 14                                  labse  ['label_da']   alt_da_eval
# 15                                  labse  ['label_en']   alt_da_eval
# 16  paraphrase-multilingual-MiniLM-L12-v2  ['label_da']      label_en
# 17                                  labse  ['label_da']   alt_en_eval
# 18  paraphrase-multilingual-MiniLM-L12-v2  ['label_en']      label_da
# 19  paraphrase-multilingual-mpnet-base-v2  ['label_da']   alt_da_eval
# 20  paraphrase-multilingual-mpnet-base-v2  ['label_da']   alt_en_eval
# 21                      all-mpnet-base-v2   ['desc_en']      label_en
# 22  paraphrase-multilingual-mpnet-base-v2  ['label_en']   alt_da_eval
# 23  paraphrase-multilingual-mpnet-base-v2  ['label_en']       desc_en
# 24                      all-mpnet-base-v2  ['label_en']       desc_en
# 25  paraphrase-multilingual-MiniLM-L12-v2  ['label_da']   alt_en_eval
# 26  paraphrase-multilingual-MiniLM-L12-v2  ['label_da']   alt_da_eval
# 27  paraphrase-multilingual-mpnet-base-v2   ['desc_en']      label_en
# 28  paraphrase-multilingual-MiniLM-L12-v2  ['label_en']       desc_en
# 29                      all-mpnet-base-v2   ['desc_en']   alt_en_eval
# 30  paraphrase-multilingual-MiniLM-L12-v2  ['label_en']   alt_da_eval
# 31  paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']      label_en
# 32  paraphrase-multilingual-mpnet-base-v2   ['desc_en']   alt_en_eval
# 33                      all-mpnet-base-v2  ['label_en']  article_eval
# 34  paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']   alt_en_eval
# 35  paraphrase-multilingual-MiniLM-L12-v2  ['label_en']  article_eval
# 36  paraphrase-multilingual-mpnet-base-v2  ['label_en']  article_eval
# 37  paraphrase-multilingual-mpnet-base-v2  ['label_en']       desc_da
# 38  paraphrase-multilingual-mpnet-base-v2   ['desc_da']      label_en
# 39  paraphrase-multilingual-mpnet-base-v2  ['label_da']       desc_da
# 40  paraphrase-multilingual-mpnet-base-v2  ['label_da']       desc_en
# 41                      all-mpnet-base-v2  ['label_da']   alt_da_eval
# 42  paraphrase-multilingual-mpnet-base-v2   ['desc_da']      label_da
# 43  paraphrase-multilingual-mpnet-base-v2   ['desc_da']   alt_en_eval
# 44  paraphrase-multilingual-mpnet-base-v2   ['desc_en']      label_da
# 45  paraphrase-multilingual-mpnet-base-v2   ['desc_en']   alt_da_eval
# 46  paraphrase-multilingual-MiniLM-L12-v2  ['label_da']       desc_da
# 47  paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']      label_en
# 48  paraphrase-multilingual-MiniLM-L12-v2  ['label_en']       desc_da
# 49  paraphrase-multilingual-MiniLM-L12-v2  ['label_da']       desc_en
# 50  paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']  article_eval
# 51  paraphrase-multilingual-mpnet-base-v2   ['desc_en']  article_eval
# 52  paraphrase-multilingual-mpnet-base-v2   ['desc_da']   alt_da_eval
# 53  paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']      label_da
# 54  paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']   alt_en_eval
# 55                      all-mpnet-base-v2   ['desc_en']  article_eval
# 56  paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']      label_da
# 57                                  labse  ['label_da']       desc_da
# 58  paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']   alt_da_eval
# 59                                  labse   ['desc_da']      label_da
# 60  paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']   alt_da_eval
# 61                                  labse  ['label_en']       desc_da
# 62  paraphrase-multilingual-mpnet-base-v2  ['label_da']  article_eval
# 63                                  labse  ['label_en']       desc_en
# 64  paraphrase-multilingual-MiniLM-L12-v2  ['label_da']  article_eval
# 65                                  labse  ['label_en']  article_eval
# 66                                  labse   ['desc_en']      label_en
# 67  paraphrase-multilingual-mpnet-base-v2   ['desc_da']  article_eval
# 68                                  labse   ['desc_da']   alt_da_eval
# 69                                  labse   ['desc_en']      label_da
# 70                                  labse   ['desc_en']   alt_da_eval
# 71                                  labse  ['label_da']       desc_en
# 72  paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']  article_eval
# 73                                  labse   ['desc_en']   alt_en_eval
# 74                                  labse   ['desc_da']      label_en
# 75                      all-mpnet-base-v2   ['desc_da']      label_da
# 76                                  labse  ['label_da']  article_eval
# 77                                  labse   ['desc_da']   alt_en_eval
# 78                                  labse   ['desc_en']  article_eval
# 79                      all-mpnet-base-v2   ['desc_da']   alt_da_eval
# 80                      all-mpnet-base-v2  ['label_da']       desc_da
# 81                                  labse   ['desc_da']  article_eval
# 82                      all-mpnet-base-v2   ['desc_da']       desc_en
# 83                      all-mpnet-base-v2  ['label_en']   alt_da_eval
# 84                      all-mpnet-base-v2   ['desc_en']       desc_da
# 85                      all-mpnet-base-v2  ['label_da']      label_en
# 86                      all-mpnet-base-v2  ['label_en']      label_da
# 87                      all-mpnet-base-v2  ['label_da']   alt_en_eval
# 88                      all-mpnet-base-v2   ['desc_da']      label_en
# 89                      all-mpnet-base-v2   ['desc_en']   alt_da_eval
# 90                      all-mpnet-base-v2   ['desc_da']   alt_en_eval
# 91                      all-mpnet-base-v2   ['desc_en']      label_da
# 92                      all-mpnet-base-v2  ['label_da']       desc_en
# 93                      all-mpnet-base-v2  ['label_en']       desc_da
# 94                      all-mpnet-base-v2  ['label_da']  article_eval
# 95                      all-mpnet-base-v2   ['desc_da']  article_eval
#
#     cardinality  skill_id_cap  skill_id_rp5  skill_id_mrr
# 0         13896      0.989597      0.999352      0.997387
# 1         13896      0.986995      0.998344      0.995047
# 2         13896      0.968193      0.992730      0.981579
# 3         13896      0.960619      0.990428      0.977549
# 4         13896      0.949071      0.984165      0.967697
# 5         13896      0.932616      0.977546      0.956374
# 6         13895      0.887437      0.962915      0.931088
# 7         13895      0.882865      0.961713      0.927780
# 8         13704      0.838396      0.929689      0.880955
# 9         13704      0.823868      0.920662      0.870823
# 10        13704      0.823612      0.915838      0.871764
# 11        13704      0.810425      0.907141      0.857923
# 12        13895      0.769176      0.891040      0.832582
# 13        13895      0.733586      0.869014      0.802251
# 14          893      0.718110      0.865881      0.790374
# 15          893      0.709617      0.868126      0.795662
# 16        13895      0.705999      0.842605      0.776726
# 17        13703      0.692142      0.845772      0.773282
# 18        13895      0.647160      0.804781      0.725988
# 19          893      0.646836      0.805836      0.731773
# 20        13703      0.625877      0.797456      0.711029
# 21        13896      0.595657      0.836140      0.708107
# 22          893      0.592898      0.778339      0.689682
# 23        13896      0.582301      0.804938      0.690908
# 24        13896      0.578350      0.808141      0.687687
# 25        13703      0.564233      0.739273      0.652653
# 26          893      0.558701      0.750842      0.651136
# 27        13896      0.558382      0.812104      0.676785
# 28        13896      0.544552      0.768265      0.652171
# 29        13704      0.533035      0.783365      0.650769
# 30          893      0.530726      0.727273      0.624901
# 31        13896      0.526066      0.771949      0.642338
# 32        13704      0.503656      0.760086      0.624156
# 33        13824      0.474412      0.714844      0.588437
# 34        13704      0.472900      0.718755      0.590046
# 35        13824      0.464716      0.689381      0.574168
# 36        13824      0.461975      0.701317      0.580202
# 37        13896      0.414882      0.657071      0.534427
# 38        13896      0.410866      0.685233      0.540996
# 39        13895      0.410478      0.651720      0.531367
# 40        13895      0.406613      0.650518      0.527415
# 41          893      0.405054      0.576880      0.490506
# 42        13895      0.381694      0.644992      0.508698
# 43        13704      0.376167      0.647018      0.505153
# 44        13895      0.369641      0.630158      0.495856
# 45          893      0.353697      0.595398      0.474199
# 46        13895      0.350775      0.577587      0.462975
# 47        13896      0.345240      0.598014      0.468720
# 48        13896      0.343120      0.571213      0.457094
# 49        13895      0.339808      0.566333      0.452660
# 50        13824      0.335768      0.564308      0.448676
# 51        13824      0.335656      0.578270      0.456034
# 52          893      0.330490      0.585859      0.456546
# 53        13895      0.320415      0.568373      0.439617
# 54        13704      0.314304      0.563587      0.435207
# 55        13824      0.307048      0.549841      0.425595
# 56        13895      0.306635      0.553035      0.426594
# 57        13895      0.301650      0.520800      0.419120
# 58          893      0.298936      0.528620      0.412647
# 59        13895      0.287534      0.514114      0.405629
# 60          893      0.283526      0.514029      0.396242
# 61        13896      0.283453      0.518532      0.410235
# 62        13824      0.280565      0.510272      0.395652
# 63        13896      0.273693      0.488375      0.390249
# 64        13824      0.257043      0.469835      0.362532
# 65        13824      0.255907      0.448134      0.365404
# 66        13896      0.247792      0.466825      0.362733
# 67        13824      0.244827      0.470703      0.360077
# 68          893      0.240281      0.454545      0.352971
# 69        13895      0.235899      0.446677      0.347263
# 70          893      0.230935      0.427609      0.339024
# 71        13895      0.230639      0.433739      0.340675
# 72        13824      0.223472      0.431785      0.327261
# 73        13704      0.221503      0.423293      0.327970
# 74        13896      0.215386      0.425590      0.326171
# 75        13895      0.192234      0.336934      0.268776
# 76        13824      0.192051      0.371962      0.294936
# 77        13704      0.187120      0.378125      0.289025
# 78        13824      0.158307      0.301722      0.239787
# 79          893      0.128422      0.237935      0.189490
# 80        13895      0.126161      0.231359      0.183768
# 81        13824      0.115429      0.241319      0.187044
# 82        13896      0.115142      0.209170      0.167145
# 83          893      0.104534      0.172840      0.140551
# 84        13896      0.098469      0.184815      0.145764
# 85        13895      0.097675      0.174019      0.137753
# 86        13895      0.093926      0.162130      0.130894
# 87        13703      0.079001      0.150464      0.115814
# 88        13896      0.065526      0.140832      0.106439
# 89          893      0.064482      0.132435      0.098667
# 90        13704      0.058844      0.129221      0.097840
# 91        13895      0.051012      0.105926      0.081188
# 92        13895      0.050596      0.103153      0.079283
# 93        13896      0.045208      0.103994      0.078633
# 94        13824      0.043876      0.094401      0.070505
# 95        13824      0.040957      0.096282      0.072033

# %%
# best model performer per "epoch" across metrics
pd.DataFrame({
    'epoch': hm['epoch'].unique()
}).assign(
    skill_id_cap=lambda df: df['epoch'].map(lambda e: hm[hm['epoch']==e].loc[hm[hm['epoch']==e]['skill_id_cap'].idxmax(), ['BASE_MODEL']].values[0]),
    skill_id_rp5=lambda df: df['epoch'].map(lambda e: hm[hm['epoch']==e].loc[hm[hm['epoch']==e]['skill_id_rp5'].idxmax(), ['BASE_MODEL']].values[0]),
    skill_id_mrr=lambda df: df['epoch'].map(lambda e: hm[hm['epoch']==e].loc[hm[hm['epoch']==e]['skill_id_mrr'].idxmax(), ['BASE_MODEL']].values[0])
)
# Out:
#           epoch       skill_id_cap       skill_id_rp5       skill_id_mrr
# 0       desc_da              labse              labse              labse
# 1      label_da              labse              labse              labse
# 2  article_eval  all-mpnet-base-v2  all-mpnet-base-v2  all-mpnet-base-v2
# 3       desc_en              labse              labse              labse
# 4      label_en              labse              labse              labse
# 5   alt_en_eval  all-mpnet-base-v2  all-mpnet-base-v2  all-mpnet-base-v2
# 6   alt_da_eval              labse              labse              labse

# %%
# best proxy performer per "epoch" across metrics
pd.DataFrame({
    'epoch': hm['epoch'].unique()
}).assign(
    skill_id_cap=lambda df: df['epoch'].map(lambda e: hm[hm['epoch']==e].loc[hm[hm['epoch']==e]['skill_id_cap'].idxmax(), ['PROXY_SETS']].values[0]),
    skill_id_rp5=lambda df: df['epoch'].map(lambda e: hm[hm['epoch']==e].loc[hm[hm['epoch']==e]['skill_id_rp5'].idxmax(), ['PROXY_SETS']].values[0]),
    skill_id_mrr=lambda df: df['epoch'].map(lambda e: hm[hm['epoch']==e].loc[hm[hm['epoch']==e]['skill_id_mrr'].idxmax(), ['PROXY_SETS']].values[0])
)
# Out:
#           epoch  skill_id_cap  skill_id_rp5  skill_id_mrr
# 0       desc_da   ['desc_en']   ['desc_en']   ['desc_en']
# 1      label_da  ['label_en']  ['label_en']  ['label_en']
# 2  article_eval  ['label_en']  ['label_en']  ['label_en']
# 3       desc_en   ['desc_da']   ['desc_da']   ['desc_da']
# 4      label_en  ['label_da']  ['label_da']  ['label_da']
# 5   alt_en_eval  ['label_en']  ['label_en']  ['label_en']
# 6   alt_da_eval  ['label_da']  ['label_en']  ['label_en']

# %%
# weighted mean metrics across "epoch" (which dataset was best predicted?)
wm = hm.groupby(['epoch']).apply(lambda x: np.average(x[['skill_id_cap', 'skill_id_rp5', 'skill_id_mrr']],
                                                           weights=x['cardinality'],
                                                           axis=0),
                                           include_groups=False)

## reshape into df with column names
wm = pd.DataFrame(wm.tolist(),
                  index=wm.index,
                  columns=['skill_id_cap', 'skill_id_rp5', 'skill_id_mrr']).reset_index()

# check
wm.sort_values(['skill_id_cap'], ascending=False).reset_index(drop=True)
# Out:
#           epoch  skill_id_cap  skill_id_rp5  skill_id_mrr
# 0       desc_en      0.502169      0.650661      0.577715
# 1   alt_en_eval      0.495318      0.663110      0.578401
# 2      label_en      0.451715      0.633837      0.542258
# 3       desc_da      0.438089      0.582037      0.512894
# 4   alt_da_eval      0.387328      0.563903      0.477148
# 5      label_da      0.375598      0.549921      0.463654
# 6  article_eval      0.262000      0.452148      0.359271

# %%
# weighted mean metrics across model and proxy
wm = hm.groupby(['BASE_MODEL', 'PROXY_SETS']).apply(lambda x: np.average(x[['skill_id_cap', 'skill_id_rp5', 'skill_id_mrr']],
                                                           weights=x['cardinality'],
                                                           axis=0),
                                           include_groups=False)

# reshape into df with column names
wm = pd.DataFrame(wm.tolist(),
                  index=wm.index,
                  columns=['skill_id_cap', 'skill_id_rp5', 'skill_id_mrr']).reset_index()

# cleanup
wm.columns = ['Model', 'Proxy', 'CAP', 'RP5', 'MRR']
wm['Proxy'] = wm['Proxy'].str[2:-2]

# check
print(wm.sort_values(['CAP'], ascending=False).reset_index(drop=True).style.hide(axis='index').to_latex().replace('_', '\_'))
wm.sort_values(['CAP'], ascending=False).reset_index(drop=True).style.hide(axis='index')
# Out:
# \begin{tabular}{llrrr}
# Model & Proxy & CAP & RP5 & MRR \\
# paraphrase-multilingual-mpnet-base-v2 & label\_en & 0.602729 & 0.790179 & 0.695283 \\
# paraphrase-multilingual-MiniLM-L12-v2 & label\_en & 0.561015 & 0.747514 & 0.652626 \\
# paraphrase-multilingual-mpnet-base-v2 & desc\_en & 0.543479 & 0.752353 & 0.644144 \\
# paraphrase-multilingual-MiniLM-L12-v2 & desc\_en & 0.512349 & 0.714872 & 0.610490 \\
# labse & label\_en & 0.506806 & 0.668862 & 0.595788 \\
# paraphrase-multilingual-mpnet-base-v2 & label\_da & 0.500302 & 0.701473 & 0.601194 \\
# paraphrase-multilingual-mpnet-base-v2 & desc\_da & 0.475005 & 0.687169 & 0.578167 \\
# labse & label\_da & 0.462794 & 0.629501 & 0.553857 \\
# paraphrase-multilingual-MiniLM-L12-v2 & label\_da & 0.444897 & 0.640447 & 0.542783 \\
# paraphrase-multilingual-MiniLM-L12-v2 & desc\_da & 0.429161 & 0.628101 & 0.526486 \\
# all-mpnet-base-v2 & label\_en & 0.400968 & 0.537808 & 0.467853 \\
# labse & desc\_en & 0.369469 & 0.526819 & 0.454121 \\
# labse & desc\_da & 0.357707 & 0.511416 & 0.440143 \\
# all-mpnet-base-v2 & desc\_en & 0.313250 & 0.486585 & 0.397718 \\
# all-mpnet-base-v2 & desc\_da & 0.095124 & 0.183426 & 0.143238 \\
# all-mpnet-base-v2 & label\_da & 0.083646 & 0.156166 & 0.122229 \\
# \end{tabular}
# <style type="text/css">
# </style>
# <table id="T_7a35b" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_7a35b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7a35b_level0_col1" class="col_heading level0 col1" >Proxy</th>
#       <th id="T_7a35b_level0_col2" class="col_heading level0 col2" >CAP</th>
#       <th id="T_7a35b_level0_col3" class="col_heading level0 col3" >RP5</th>
#       <th id="T_7a35b_level0_col4" class="col_heading level0 col4" >MRR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7a35b_row0_col0" class="data row0 col0" >paraphrase-multilingual-mpnet-base-v2</td>
#       <td id="T_7a35b_row0_col1" class="data row0 col1" >label_en</td>
#       <td id="T_7a35b_row0_col2" class="data row0 col2" >0.602729</td>
#       <td id="T_7a35b_row0_col3" class="data row0 col3" >0.790179</td>
#       <td id="T_7a35b_row0_col4" class="data row0 col4" >0.695283</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row1_col0" class="data row1 col0" >paraphrase-multilingual-MiniLM-L12-v2</td>
#       <td id="T_7a35b_row1_col1" class="data row1 col1" >label_en</td>
#       <td id="T_7a35b_row1_col2" class="data row1 col2" >0.561015</td>
#       <td id="T_7a35b_row1_col3" class="data row1 col3" >0.747514</td>
#       <td id="T_7a35b_row1_col4" class="data row1 col4" >0.652626</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row2_col0" class="data row2 col0" >paraphrase-multilingual-mpnet-base-v2</td>
#       <td id="T_7a35b_row2_col1" class="data row2 col1" >desc_en</td>
#       <td id="T_7a35b_row2_col2" class="data row2 col2" >0.543479</td>
#       <td id="T_7a35b_row2_col3" class="data row2 col3" >0.752353</td>
#       <td id="T_7a35b_row2_col4" class="data row2 col4" >0.644144</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row3_col0" class="data row3 col0" >paraphrase-multilingual-MiniLM-L12-v2</td>
#       <td id="T_7a35b_row3_col1" class="data row3 col1" >desc_en</td>
#       <td id="T_7a35b_row3_col2" class="data row3 col2" >0.512349</td>
#       <td id="T_7a35b_row3_col3" class="data row3 col3" >0.714872</td>
#       <td id="T_7a35b_row3_col4" class="data row3 col4" >0.610490</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row4_col0" class="data row4 col0" >labse</td>
#       <td id="T_7a35b_row4_col1" class="data row4 col1" >label_en</td>
#       <td id="T_7a35b_row4_col2" class="data row4 col2" >0.506806</td>
#       <td id="T_7a35b_row4_col3" class="data row4 col3" >0.668862</td>
#       <td id="T_7a35b_row4_col4" class="data row4 col4" >0.595788</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row5_col0" class="data row5 col0" >paraphrase-multilingual-mpnet-base-v2</td>
#       <td id="T_7a35b_row5_col1" class="data row5 col1" >label_da</td>
#       <td id="T_7a35b_row5_col2" class="data row5 col2" >0.500302</td>
#       <td id="T_7a35b_row5_col3" class="data row5 col3" >0.701473</td>
#       <td id="T_7a35b_row5_col4" class="data row5 col4" >0.601194</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row6_col0" class="data row6 col0" >paraphrase-multilingual-mpnet-base-v2</td>
#       <td id="T_7a35b_row6_col1" class="data row6 col1" >desc_da</td>
#       <td id="T_7a35b_row6_col2" class="data row6 col2" >0.475005</td>
#       <td id="T_7a35b_row6_col3" class="data row6 col3" >0.687169</td>
#       <td id="T_7a35b_row6_col4" class="data row6 col4" >0.578167</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row7_col0" class="data row7 col0" >labse</td>
#       <td id="T_7a35b_row7_col1" class="data row7 col1" >label_da</td>
#       <td id="T_7a35b_row7_col2" class="data row7 col2" >0.462794</td>
#       <td id="T_7a35b_row7_col3" class="data row7 col3" >0.629501</td>
#       <td id="T_7a35b_row7_col4" class="data row7 col4" >0.553857</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row8_col0" class="data row8 col0" >paraphrase-multilingual-MiniLM-L12-v2</td>
#       <td id="T_7a35b_row8_col1" class="data row8 col1" >label_da</td>
#       <td id="T_7a35b_row8_col2" class="data row8 col2" >0.444897</td>
#       <td id="T_7a35b_row8_col3" class="data row8 col3" >0.640447</td>
#       <td id="T_7a35b_row8_col4" class="data row8 col4" >0.542783</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row9_col0" class="data row9 col0" >paraphrase-multilingual-MiniLM-L12-v2</td>
#       <td id="T_7a35b_row9_col1" class="data row9 col1" >desc_da</td>
#       <td id="T_7a35b_row9_col2" class="data row9 col2" >0.429161</td>
#       <td id="T_7a35b_row9_col3" class="data row9 col3" >0.628101</td>
#       <td id="T_7a35b_row9_col4" class="data row9 col4" >0.526486</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row10_col0" class="data row10 col0" >all-mpnet-base-v2</td>
#       <td id="T_7a35b_row10_col1" class="data row10 col1" >label_en</td>
#       <td id="T_7a35b_row10_col2" class="data row10 col2" >0.400968</td>
#       <td id="T_7a35b_row10_col3" class="data row10 col3" >0.537808</td>
#       <td id="T_7a35b_row10_col4" class="data row10 col4" >0.467853</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row11_col0" class="data row11 col0" >labse</td>
#       <td id="T_7a35b_row11_col1" class="data row11 col1" >desc_en</td>
#       <td id="T_7a35b_row11_col2" class="data row11 col2" >0.369469</td>
#       <td id="T_7a35b_row11_col3" class="data row11 col3" >0.526819</td>
#       <td id="T_7a35b_row11_col4" class="data row11 col4" >0.454121</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row12_col0" class="data row12 col0" >labse</td>
#       <td id="T_7a35b_row12_col1" class="data row12 col1" >desc_da</td>
#       <td id="T_7a35b_row12_col2" class="data row12 col2" >0.357707</td>
#       <td id="T_7a35b_row12_col3" class="data row12 col3" >0.511416</td>
#       <td id="T_7a35b_row12_col4" class="data row12 col4" >0.440143</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row13_col0" class="data row13 col0" >all-mpnet-base-v2</td>
#       <td id="T_7a35b_row13_col1" class="data row13 col1" >desc_en</td>
#       <td id="T_7a35b_row13_col2" class="data row13 col2" >0.313250</td>
#       <td id="T_7a35b_row13_col3" class="data row13 col3" >0.486585</td>
#       <td id="T_7a35b_row13_col4" class="data row13 col4" >0.397718</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row14_col0" class="data row14 col0" >all-mpnet-base-v2</td>
#       <td id="T_7a35b_row14_col1" class="data row14 col1" >desc_da</td>
#       <td id="T_7a35b_row14_col2" class="data row14 col2" >0.095124</td>
#       <td id="T_7a35b_row14_col3" class="data row14 col3" >0.183426</td>
#       <td id="T_7a35b_row14_col4" class="data row14 col4" >0.143238</td>
#     </tr>
#     <tr>
#       <td id="T_7a35b_row15_col0" class="data row15 col0" >all-mpnet-base-v2</td>
#       <td id="T_7a35b_row15_col1" class="data row15 col1" >label_da</td>
#       <td id="T_7a35b_row15_col2" class="data row15 col2" >0.083646</td>
#       <td id="T_7a35b_row15_col3" class="data row15 col3" >0.156166</td>
#       <td id="T_7a35b_row15_col4" class="data row15 col4" >0.122229</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Base Model and Skill Proxy Post-Validation

# %%
# trial
df = pd.read_csv(work_dir('trials', 'base_model.csv')).drop_duplicates(subset=['BASE_MODEL', 'PROXY_SETS', 'epoch'])
df = df.assign(BASE_MODEL=df['BASE_MODEL'].str.replace('sentence-transformers/', ''))

hm = (df.loc[df['epoch'].isin(['val']),
             ['BASE_MODEL', 'PROXY_SETS', 'epoch', 'cardinality', 'skill_id_cap', 'skill_id_rp5', 'skill_id_mrr']])

# check
print(hm.shape)
print(hm['BASE_MODEL'].value_counts())
hm.sort_values(['skill_id_cap'], ascending=False).reset_index(drop=True)
# Out:
# (16, 7)
# BASE_MODEL
# paraphrase-multilingual-mpnet-base-v2    4
# all-mpnet-base-v2                        4
# labse                                    4
# paraphrase-multilingual-MiniLM-L12-v2    4
# Name: count, dtype: int64
#                                BASE_MODEL    PROXY_SETS epoch  cardinality  \
# 0   paraphrase-multilingual-mpnet-base-v2  ['label_en']   val        25601
# 1   paraphrase-multilingual-mpnet-base-v2  ['label_da']   val        25601
# 2   paraphrase-multilingual-MiniLM-L12-v2  ['label_en']   val        25601
# 3   paraphrase-multilingual-mpnet-base-v2   ['desc_en']   val        25601
# 4   paraphrase-multilingual-MiniLM-L12-v2  ['label_da']   val        25601
# 5   paraphrase-multilingual-mpnet-base-v2   ['desc_da']   val        25601
# 6   paraphrase-multilingual-MiniLM-L12-v2   ['desc_en']   val        25601
# 7   paraphrase-multilingual-MiniLM-L12-v2   ['desc_da']   val        25601
# 8                                   labse  ['label_en']   val        25601
# 9                                   labse  ['label_da']   val        25601
# 10                      all-mpnet-base-v2  ['label_en']   val        25601
# 11                                  labse   ['desc_en']   val        25601
# 12                                  labse   ['desc_da']   val        25601
# 13                      all-mpnet-base-v2   ['desc_en']   val        25601
# 14                      all-mpnet-base-v2  ['label_da']   val        25601
# 15                      all-mpnet-base-v2   ['desc_da']   val        25601
#
#     skill_id_cap  skill_id_rp5  skill_id_mrr
# 0       0.324589      0.363954      0.497371
# 1       0.262193      0.286523      0.422372
# 2       0.245772      0.269913      0.396966
# 3       0.206249      0.220330      0.347599
# 4       0.192354      0.206831      0.330342
# 5       0.175664      0.193650      0.311229
# 6       0.165371      0.173301      0.286691
# 7       0.142172      0.153589      0.258111
# 8       0.118447      0.134231      0.229381
# 9       0.108036      0.118659      0.209093
# 10      0.084058      0.080245      0.133037
# 11      0.067917      0.078837      0.148815
# 12      0.065978      0.076828      0.144921
# 13      0.046026      0.048595      0.087912
# 14      0.032546      0.032510      0.067981
# 15      0.024140      0.027053      0.059054
