# %%
# dependencies
import os
import re
import numpy as np
import pandas as pd
from transformers import AutoTokenizer
from google.colab import drive, userdata

# file management
drive.mount('/content/drive')
WORK_DIR = '/content/drive/MyDrive/Projects/skillextraction'

# work dir shortcut function
def work_dir(*args):
    return os.path.join(WORK_DIR, *args)
# Out:
# Mounted at /content/drive

# %%
# load raw sentences from crawled Danish job ads (ignore null)
df = pd.read_csv(work_dir('Data', 'raw_sentences.csv')).dropna()

# check
print(df.shape)
df.head(3)
# Out:
# (9220716, 3)
#    id                                         completion  frequency
# 0   1  Advokat til afdeling for fast ejendom og entre...          1
# 1   2  Til et spændende og udfordrende job hos Haugaa...          1
# 2   3  Vores afdeling for fast ejendom og entreprise ...          1

# %%
# examine most frequent (use interactive table)
df.sort_values('frequency', ascending=False)
# Out:
#               id                                         completion  frequency
# 900          901                                         Indrykket:     178661
# 1303        1304                                              Ansøg     157853
# 1046945  1046946                           Antal ledige stillinger:     131938
# 173          174  Skriv venligst i din ansøgning at du fandt job...     125247
# 3082008  3082009                                            QUICKNR     111371
# ...          ...                                                ...        ...
# 3937590  3937591  Samtaler afholdes: 27. februar 2023 (hele dagen).          1
# 3937589  3937590  Stillingen løber fra 1. april 2023 til og med ...          1
# 3937586  3937587  Stillingen er med forventet tiltrædelse hurtig...          1
# 3937584  3937585  Lyder ovenstående som et job, der kunne passe ...          1
# 9220720  9220721  Ansøgningsfristen er tirsdag d. 17.august kl. ...          1
#
# [9220716 rows x 3 columns]

# %%
# the 2000 most frequent with few identified exceptions are nonskills
frequent_df = df.sort_values('frequency', ascending=False)[~df.index.isin((3255, 3256, 126927, 21507, 708, 14070, 395445, 395444, 395446, 395441, 736,
                                                                           7615, 17183, 193, 3002, 125646, 72683, 149853, 48619, 192642, 259520, 21541))].head(2000)

# rename completion to sentence and ignore other columns
frequent_df = frequent_df.rename(columns={'completion': 'sentence'})[['sentence']]

# check
print(frequent_df.shape)
frequent_df.head(3)
# Out:
# (2000, 1)
#                          sentence
# 900                    Indrykket:
# 1303                        Ansøg
# 1046945  Antal ledige stillinger:

# %%
# conditions to check for url, email, phone and date (latter more complex)
has_url = r'\b(https?\:\/\/|www\.)\S+(?![\'\",])'
has_email = r'\b([a-z0-9\.\-\_]+)?@[a-z0-9\.\-\_]+\b'
has_phone = r'(?<!\w)(\((?:\+|00)[0-9]{2}\))?(?: ?[0-9]{2,} ?){4,}(?!\w)'

# define written date parts
weekdays = ['man', 'mon', 'mandag', 'monday', 'tir', 'tue', 'tirsdag', 'ons', 'wed', 'onsdag', 'wednesday', 'tor', 'thi', 'torsdag', 'thirsday',
            'fre', 'fri', 'fredag', 'friday', 'lør', 'sat', 'lørdag', 'saturday', 'søn', 'sun', 'søndag', 'sunday']
months = ['jan', 'januar', 'january', 'feb', 'februar', 'february', 'mar', 'marts', 'march', 'apr', 'april', 'maj', 'may', 'jun', 'juni', 'june',
          'jul', 'juli', 'july', 'aug', 'august', 'sep', 'september', 'okt', 'oct', 'oktober', 'october', 'nov', 'november', 'dec', 'december']

# define imploded date parts
weekday = r'(' + r'|'.join([r'\b%s\b' % w for w in sorted(weekdays, key=len, reverse=True)]) + r')'
month = r'(' + r'|'.join([r'\b%s\b' % m for m in sorted(months, key=len, reverse=True)]) + r')'

# define more date parts
dd = r'((3[0-1]|[1-2][0-9]|0?[1-9])(\.|st|nd|rd|th)?)'
mm = r'(1[0-2]|0?[1-9])'
yy = r'((19|20)?[0-9]{2})'
hh = r'(2[0-3]|[0-1]?[0-9])'
mm = r'([0-5][0-9])'
the = r'((the|d|den|per|pr)\.?)'
at = r'(at|kl\.?)'
of = r'(of)'
ampm = '(am|pm)'
w_sep = r' ?,? ?'
d_sep = r'[\.\-\/]'
t_sep = r'[\:\.]'
q = r'?'
time = r'(' + at + w_sep + hh + t_sep + q + mm + q + t_sep + q + mm + q + w_sep + ampm + q + r')'

# assemble date patterns
has_date_1 = weekday + q + w_sep + the + q + w_sep + dd + w_sep + of + q + w_sep + month + w_sep + yy + q + w_sep + time + q
has_date_2 = weekday + q + w_sep + month + w_sep + the + q + w_sep + dd + w_sep + yy + w_sep + time + q

# %%
# filter based on occurence of either url, email, phone or date
filtered_df = df[
    df['completion'].str.contains(has_url, regex=True, flags=re.IGNORECASE)
    | df['completion'].str.contains(has_email, regex=True, flags=re.IGNORECASE)
    | df['completion'].str.contains(has_phone, regex=True, flags=re.IGNORECASE)
    | df['completion'].str.contains(has_date_1, regex=True, flags=re.IGNORECASE)
    | df['completion'].str.contains(has_date_2, regex=True, flags=re.IGNORECASE)
]

# rename completion to sentence and ignore other columns
filtered_df = filtered_df.rename(columns={'completion': 'sentence'})[['sentence']].copy()

# check
print(filtered_df.shape)
filtered_df.head(3)
# Out:
# <ipython-input-6-0d05a403325c>:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df['completion'].str.contains(has_url, regex=True, flags=re.IGNORECASE)
# <ipython-input-6-0d05a403325c>:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   | df['completion'].str.contains(has_email, regex=True, flags=re.IGNORECASE)
# <ipython-input-6-0d05a403325c>:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   | df['completion'].str.contains(has_phone, regex=True, flags=re.IGNORECASE)
# <ipython-input-6-0d05a403325c>:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   | df['completion'].str.contains(has_date_1, regex=True, flags=re.IGNORECASE)
# <ipython-input-6-0d05a403325c>:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   | df['completion'].str.contains(has_date_2, regex=True, flags=re.IGNORECASE)
# (1074115, 1)
#                                              sentence
# 19  Ansøgningsfrist: fredag den 23. februar 2024 m...
# 22  Advokat Rasmus Haugaard, rh@haugaardbraad.dk, ...
# 23  Hvis du vil vide mere om stillingen, og os som...

# %%
# examine filtered (use interactive table)
filtered_df.sample(20000, random_state=7)
# Out:
#                                                   sentence
# 8691617  Please submit your application and CV in Engli...
# 8112814  En kort ansøgning med CV, eksamensprotokoludsk...
# 6761322  Ved opfølgende spørgsmål, er du velkommen til ...
# 5644116  Så send en kortfattet ansøgning og dit CV - en...
# 320899   Praktiske oplysninger: Ansøgningsfrist: 12. ja...
# ...                                                    ...
# 8746908  Ansøgningsfristen er 10. oktober 2021. Der er ...
# 8241021  Hvis du ønsker at besøge os i afdelingen eller...
# 8843627  Stillingen er ledig til besættelse den 1. dece...
# 4751622  Har du spørgsmål i øvrigt, er du velkommen til...
# 3240488  Any questions about the position may be direct...
#
# [20000 rows x 1 columns]

# %%
# identified condition to check for high risk sentences
has_risk = r'flair for|stærk i|strong in|erfaren i|experienced in|med erfaring i|with experience in'

# check filtered results
filtered_df[~filtered_df['sentence'].str.contains(has_risk, regex=True, flags=re.IGNORECASE)]['sentence'].tolist()
# Out:
# ['Ansøgningsfrist: fredag den 23. februar 2024 med tiltrædelse snarest muligt derefter.',
#  'Advokat Rasmus Haugaard, rh@haugaardbraad.dk, mærket "advokat til fast ejendom og entreprise" i emnelinjen.',
#  'Hvis du vil vide mere om stillingen, og os som virksomhed, er du velkommen til at kontakte: Rasmus Haugaard på telefon 30785132 - rh@haugaardbraad.dk eller Anders Braad på telefon 30685340 – ab@haugaardbraad.dk.',
#  'For further details or information please contact Peter Højlund, mobile + 45 5175 5079 or peter.hojlund@dnv.com',
#  'Send os din ansøgning på kolding-u@jobteam.dk, og vi vil kontakte dig snarest.',
#  'Yderligere oplysninger om stillingen kan fås ved henvendelse til afdelingsleder Dorte Marie Jensen på mail dmij@aarhus.dk eller tlf. 8713 3944 samt afdelingsleder Anita Gandrup Ernst på mail angae@aarhus.dk eller tlf. 4185 6590.',
#  'Ansøgning med relevante bilag skal være modtaget senest søndag den 18. februar 2024.',
#  'Tiltrædelse: 1. april 2024.',
#  'https://www.aarhus.dk/demokrati/politikker-og-planer/erhverv-og-beskaeftigelse/',
#  'Ansøgning sendes til medarbejder@cleanrooms.dk.',
#  'Hvis du skulle have nogle spørgsmål angående stillingen, så skal du være velkommen til at kontakte Allan Due på 40 90 10 01, på hverdage mellem kl. 9 og kl. 15.',
#  'Hvis du har spørgsmål til stillingen, er du velkommen til at kontakte Store Manager Maja Knutsson på tlf. nr.: 86420481',
#  'Læs mere her, og bliv klogere på den grønne omstilling, du måske ikke havde regnet med, at du kunne blive en del af https://www.circlek.dk/groenomstilling',
#  'Du er velkommen til at kontakte Uddeler Anne Kirstine Christensen på telefon 75 85 11 44 – eller kig forbi butikken til en snak.',
#  'Send din ansøgning via "Ansøg nu" senest den 29. februar 2024. Vi afholder samtaler løbende og ønsker at ansætte fra 1. marts, så tøv ikke med at sende din ansøgning!',
#  'Vi søger fra 1. oktober en ny kollega - kunne det mon være dig?',
#  'Ansøgning pr. mail foretrækkes: itmagicjob@gmail.com',
#  'Har du yderligere spørgsmål til stillingen, er du velkommen til at kontakte Serviceleder Søren Beck på telefon 21 79 92 98.',
#  'Yderligere information kan indhentes hos Daglig leder Conni Valentin Hansen eller Sharonell Sanders på tlf.: 88 72 46 37 mellem kl. 8-14.',
#  'Vi skal gerne have din ansøgning senest mandag den 26. februar kl. 12 og samtaler afholdes løbende, og stillingsopslaget fjernes når den rigtige medarbejder er fundet.',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte Uffe Binderup Jensen, Head of Service - HMF Danmark, på mobil: +45 6023 4523 eller mail: ubj@hmf.dk.',
#  '+45 86 27 08 00',
#  'www.hmfcranes.com',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte servicechef Morten Kloster på tlf.: 40184382, på mail mkl@idealcombi.dk eller læse mere om Idealcombi på www.idealcombi.dk.',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte teknisk chef Thomas Olsen på tlf. 51 16 07 74.',
#  'Pr. 1. marts 2021 blev to af to af Orklas succesfulde forretninger i Danmark lagt sammen, så Orkla Foods Danmark og Orkla Confectionery & Snacks Danmark fremover opererer med én samlet ledelse under navnet Orkla Danmark.',
#  'Radiometer Medical ApS | Åkandevej 21 | DK-2700 | Brønshøj | Denmark | Phone +45 38 27 38 27',
#  'Oversygeplejerske Bibbi From 23666851 eller TR Rie Johansen, tlf. 30 585748',
#  'Oplysninger om psykiatrisygehuset fås på www.psykiatrienisyddanmark.dk',
#  'Opstart: Mandag d. 12. februar 2024 kl. 07:00.',
#  'Varighed: Fra d. 12. februar til d. 16. februar 2024 (Hele uge 7).',
#  'Hvis du har de rette kvalifikationer og ønsker at blive en del af vores team, bedes du sende din ansøgning og dit CV til Ann Færgeman: AFJ@jobteam.dk.',
#  'afj@jobteam.dk',
#  '93632510',
#  'Kontakt os på mail: Par@jobteam.dk , mærket "Pladesmed"',
#  'Eller på tlf: 54 55 12 30',
#  'Par@jobteam.dk',
#  '21541034',
#  'Læs mere om skolen og vores mellemtrin/udskoling på hjemmesiden: www.skaade-skole.dk',
#  'Ansøgere er velkomne til at kontakte skoleleder Mogens Steen Petersen (2920 7997) eller pædagogisk leder for mellemtrin/udskolingen Rasmus Langballe (2037 0081) for yderligere information.',
#  'Ansøgningsfristen er den 19. februar 2024',
#  'Vi afholder samtaler tirsdag eftermiddag d. 21. februar 2024',
#  'Ansøgningsfrist 19 februar, men samtaler tages løbende.',
#  'Ansøgning skal sendes på mail: info@biketag.com',
#  'Jobbet søges kun via email: konditorjob@bodenhoffs.dk',
#  'Du kan også kontakte butikschef Lotte på telefon 27793134 - eller kigge forbi butikken og få en snak.',
#  'Ansøg via "Ansøg nu" senest den 29. februar 2024',
#  'Du er velkommen til at kontakte Uddeler John Søndergaard Pedersen på telefon 86658026 – eller kig forbi butikken til en snak.',
#  'Send din ansøgning via "Ansøg nu" senest den 4. Marts 2024',
#  'Send din ansøgning via "Ansøg nu" senest den 5. marts 2024',
#  'Er du interesseret i jobbet, så send din ansøgning til os via vores ansøgningsformular inden den 22. februar.',
#  'Vi holder samtaler mandag den 26. februar.',
#  'Har du spørgsmål til jobbet, er du velkommen til at kontakte teamleder Mikkel Jørgensen på tlf. 7912 8097 eller mail mijo@detfagligehus.dk.',
#  '22. februar 2024',
#  '1. april 2024',
#  'Vi skal have din ansøgning senest den 21. februar.',
#  'Hvis du har spørgsmål til jobbet, er du velkommen til at kontakte kommunikationschef Marianne Grundsøe på telefon 2938 2501.',
#  'Hvis du har spørgsmål eller brug for yderligere oplysninger er du velkommen til at kontakte leder ved Fabianhus Ricko Ginnerup på telefon 72 49 77 36 eller sygeplejerske Lone Richardt på telefon 72 49 67 43Løn- og ansættelsesvilkår',
#  'Løn- og ansættelsesvilkår efter gældende overenskomst med tiltrædelse den 1. maj 2024 eller efter aftale.Ansøgningsfrist',
#  'Vi glæder os til at modtage din ansøgning, som skal være modtaget senest den 22. marts 2024.',
#  'Vi holder ansættelsessamtaler den 25. marts 2024.',
#  'Ansøgningsfrist: 22. marts 2024',
#  'Stillingen er på 37 timer ugentligt og til besættelse fra den 1. april 2024 eller efter aftale.',
#  'For yderligere information kontakt også faglig leder Mia Juncher-Olsen på 2057 1004.',
#  'Søg via linket senest mandag den 19. februar 2024',
#  'Hvis du vil vide mere om jobbet, og hvordan du kan være med til at skabe en god arbejdsplads på Gnisten er du velkommen til at kontakte afdelingsleder af Plejeboligenheden Marianne Frost på telefon 20 34 30 02 eller på mail: mafr@skivekommune.dk.',
#  'Hvis du har spørgsmål vedr. Gnisten eller ønsker at besøge os kan du kontakte områdeleder på Marienlyst Annette Siig Toft på mail anto@skivekommune.dk',
#  'Send os din ansøgning senest den 25. februar 2024.',
#  'Vi holder samtaler den 5. marts 2024, og vi håber, at du kan tiltræde pr. 1. maj 2024 eller efter aftale.',
#  'Vil du vide mere om stillingen, så kan du kontakte afdelingsleder Shqipe Rama Schmidt tlf.: 27 90 02 53, eller jobformidler Anne Gitte Fischer Petersen tlf.: 40 28 43 05',
#  'Tiltrædelse hurtigst muligt eller senest den 1. maj 2024.',
#  'Ansøgningsfristen er den 10. marts 2024. Vi forventer at holde ansættelsessamtaler den 18. marts 2024.',
#  'Kontakt os: Telefon: 27 50 01 00',
#  'If you have questions, please do not hesitate to contact Sara Juhl via sj@bloom.dk or +45 2086 0865.',
#  'April 2024. Første udeperiode er fra den 10. april til 12. juni 2024',
#  'Du er velkommen til at kontakte Stationslederen på telefon +299 389464 eller E-mail: maasi@tusass.gl hvis du vil vide mere om stillingen.',
#  'Søg stillingen online via Tusass job-portal vedhæftet ansøgning og CV senest :18. Feb.',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte Teamleder Lene Skjærbæk på tlf. 87471140.',
#  'Publiceret6. februar 2024',
#  'KontaktLene SkjærbækLesk@viabiler.dk87 47 11 40',
#  'Stillingen skal søges via din profil på www.duos.dk og har du spørgsmål til stillingen, kan ledsageteamet kontaktes på tlf. 36 34 81 28.',
#  'Har du spørgsmål er du altid velkommen til at kontakte Ledsageteamet på tlf. 3634 8128',
#  'Du må gerne sende os en besked via mail til hotline@landbobanken.dk , så vi kan rette fejlen.',
#  "Kontakt Jesper Nielsen eller Rebekka Platz hos PeopleLink på 6610 2015 for yderligere oplysninger, eller send os din ansøgning og dit CV via 'Søg stillingen' hurtigst muligt.",
#  'Der vil løbende blive afholdt samtaler, send derfor ansøgning hurtigst mulig til ttp@jobteam.dk.',
#  'Og har du yderligere spørgsmål til stillingen er du velkommen til at ringe på 54589656',
#  'ttp@jobteam.dk',
#  '54589656',
#  'https://clerk.io',
#  'Kontakta kontorsansvarig, Martin Sabel, via e-post msb@le34.se eller',
#  '+46 (0)72-401 43 22 eller VD Mickael Holgersson, via e-post mic@le34.se',
#  'Stillingen ønskes besat 1. marts 2024 eller hurtigst muligt derefter.',
#  "Flere oplysninger om jobbet og programmet fås ved henvendelse til 3F International leder, Jesper Nielsen (+45 88920470, 30329308). Læs mere om 3F's internationale udviklingsarbejde på 3F International - vi arbejder på tværs af grænser.",
#  'Send din ansøgning og CV ved at klikke på "søg stillingen" senest den 19. februar 2024.',
#  'Læs mere om os på www.3f.dk.',
#  'Har du spørgsmål til jobbet, kan du kontakte Seniorkonsulent Nadia Deis nadia.deis@3f.dk, +32 474 98 15 79',
#  'Praktikforløbet efteråret 2024 er fra d. 26. august 2024 til d. 31. januar 2025.',
#  'Praktikforløbet foråret 2025 er fra d. 1. februar 2025 til d. 15. juli 2025.',
#  'Send din ansøgning og CV ved at klikke på "søg stilling" senest torsdag den 22. februar 2024 kl. 9.00.',
#  'Please send your application and CV to our job portal - https://job.aalund.com/',
#  'For more information see: http://www.aalund.com',
#  'Tiltrædelse 1. april 2024',
#  'Ansøgningsfrist er den 21. februar 2024',
#  'Ønsker du at vide mere, kan du hente vores virksomhedsplan samt yderligere oplysninger om Ældrecentret Nygårds Plads på vores hjemmeside: www.brondby.dk/nygaardsplads',
#  'Du er også meget velkommen til at kontakte centerleder Marianne Strømsted på mobil 2120 7140, afdelingslederne Hanne Schmidt på mobil 2434 9210 eller Amina Kastberg Polat mobil på 4024 6990',
#  'Hvis du skulle have nogle spørgsmål angående stillingen, så skal du være velkommen til at kontakte Allan Due på 40 90 10 01 – Mandag til fredag mellem kl. 9.00 og kl. 15.00.',
#  'Send venligst ansøgning og CV til info@danepork.dk.',
#  '45 93 32 41',
#  'Send din ansøgning via "søg job" senest d. 10. marts 2024',
#  'Se bort fra ansøgningsfristen og søg i dag ved at sende os en mail på kontakt@magnumopus.dk med ansøgning og CV.',
#  'Hvis du har yderligere spørgsmål til stillingen, er du er velkommen til at kontakte leder af Visitation og Hjælpemidler Katrine E. Pfeiffer på telefon 72 49 74 70 eller på mail: kepfe@gribskov.dk eller visitator Charlotte Juul Madsen på telefon 72 49 ...',
#  'Center for Sundhed og Omsorg i Gribskov Kommune er pr. 1. juni 2023 flyttet ind i det nye administrations- og sundhedshus på Østergade 62, 3200 Helsinge.',
#  'Vi ser frem til at modtage din ansøgning og cv, samt andre relevante dokumenter, senest 19. februar 2024. 23:59',
#  '1. samtale er torsdag den 22. februar 2024 og evt. 2. samtale aftales.',
#  'Vi forventer, du kan begynde den 1. april 2024.',
#  'Ansøgningsfrist: 19. februar 2024',
#  'Send din ansøgning til job@hojhuset.com',
#  'Har du spørgsmål til stillingen kontakt: Brita Laugesen tlf. +45 61634633',
#  'Du kan læse mere om os på www.koldkur.dk',
#  'Hvis jobbet lyder som noget for dig, så send din ansøgning og CV til Jesper Frederiksen – jkf@hansjensen.eu.',
#  'Så hurtigt som muligt og senest den 15-02-2024 – Har du spørgsmål til stillingen er du velkommen til at kontakte Jesper på 51 35 66 38',
#  'Butikschef Emre Kilic på tlf. 52 39 17 80.',
#  'Ansøgning og CV sendes pr. mail til csilla@j-m-r.dk',
#  'Stillingen ønskes besat 1. april eller snarest muligt derefter.',
#  'Du opfordres til at kontaktevicecenterleder Professor Ingo Zettler på ingo.zettler@psy.ku.dk eller centerleder Professor Morten Axel Pedersen på map@sodas.ku.dk, hvis du har spørgsmål til dette eller ønsker at høre mere til stillingen.',
#  'Du kan få mere information om SODAS på https://sodas.ku.dk',
#  'Ansøgningsfrist er mandag den 4. marts 2024.',
#  'Stillingerne er med ansættelse på 34-37 timer (efter aftale) – Kom og få en rundvisning, ring på 2898 1660',
#  'Kontakt Leder Rune på 2898 1660, eller afd.',
#  'Leder Michael på 2898 0369',
#  'Stillingen er ledig fra 1. marts eller hurtigst muligt.',
#  'Har du spørgsmål til stillingen er du altid velkommen til at kontakte Aage Lykke Andersen på tlf. +45 25 42 78 78 eller ala@mariendal.dk.',
#  'Er jobbet her noget for dig, kender du nogle som kunne være interesserede i en af de ledige stillinger, så send os en mail på p.bornaes@newrest.eu',
#  'Send din ansøgning og CV til job@norfolk.dk',
#  'For further information, please contact Kevin Wollbrink, VP R&ED Finance +45 30757954.',
#  '14 February 2024.',
#  'For further information, please contact Joan Toftegaard Boesen, VP Development Finance +45 30777995.',
#  '18 February 2024.',
#  'For further information, please contact Liselotte Hyveled at +45 44448888.',
#  '18. februar 2024',
#  'Ansøgningsfristen er d. 18. februar 2024. Vi behandler ansøgninger løbende - så send derfor din ansøgning allerede i dag.',
#  'Læs mere om Restaurant Flammen på www.restaurant-flammen.dk.',
#  'Du kan læse mere om os på www.servicekompagniet.dk',
#  'Såfremt du mener du er den rette kandidat, bedes du sende en mail til mbs@servicekompagniet.dk.',
#  'Vi søger en ambitiøs og engageret socialrådgiver/socialformidler til beskæftigelsesområdet pr. 1. april 2024 eller hurtigst muligt.',
#  'Stillingen er til besættelse med virkning fra den 1. april 2024 eller hurtigst muligt.',
#  'Du kan få yderligere oplysninger om stillingen hos faglig koordinator Mette Graabach på telefon 3010 5479 eller Job- og Borgerservicechef Lene Britt Jørgensen på telefon 2520 8807.',
#  'Ansøgningsfristen udløber fredag den 23. februar 2024 kl. 8.00. Ansættelsessamtaler forventes at finde sted tirsdag den 27.2.2024.',
#  'Så kan du læse meget mere om livet på Samsø på www.tidtilsamsoe.dk eller følge med på både Instagram på @tidtilsamsoe og Facebook på @tidtilsamsoe.',
#  'Du kan læse mere om Samsø Kommune på kommunens hjemmeside https://www.samsoe.dk/',
#  'Jens - Sjøren tlf 98963233',
#  'Vi er lige nu en del af Holmeå Børnecenter, men fra 1. april skal vi ind under områdeledelsen i Vejen Kommune.',
#  'Vi afholder ansættelsessamtaler mandag d. 26. februar',
#  'Har du spørgsmål eller andet er du velkommen til at kontakte leder Jette Korsgaard 23806552 eller kommende leder Kirsten Houlind 24758149',
#  'Har du spørgsmål til jobbet, er du velkommen til at kontakte Regionsleder Bjarke Kudahl på tlf. 40268816.',
#  'Upload CV og ansøgning via vores hjemmeside: https://www.vikingdanmark.dk/da-dk/ledige-stillinger inden d.18. februar 2024.',
#  'Har du spørgsmål er du altid velkommen til at kontakte Ledsageteamet på tlf. 3634 7900',
#  'Har overstående vakt din interesse, er du velkommen til at sende en ansøgning, CV samt evt. referencer til job@dentist.dk.',
#  'Eller du kan ringe til Majbritt for nærmere information 20 77 32 66',
#  'job@dentist.dk: Website',
#  'https://dentist.dk/alle-klinikker/roedding/: Se også',
#  'https://dentist.dk/alle-klinikker/roedding/',
#  'Vil du være en del af vores vikarteam, skal du sende en ansøgning til christa@dukasku.dk',
#  'Du er velkommen til at kontakte IKEA Food Team Leader Ralph Petersen (ralph.petersen@ingka.ikea.com) ved spørgsmål.',
#  "Contract level: I-CA 1 Contract duration: Ongoing ICA – 'Open-ended, subject to organizational requirements, availability of funds and satisfactory performance.' For more details about the ICA contractual modality, please follow this link: https://www ...",
#  'Henvendelse til Tina Benzon 23438762',
#  'Send din ansøgning til info@tandlaegehusetharlev.dk Har du spørgsmål eller ønsker anden information, så kontakt Mads Gaardmand på tlf:21495905: Kontakt Tandlægehuset Harlev',
#  'info@tandlaegehusetharlev.dk: Website',
#  'www.tandlaegehusetharlev.dk: Se også',
#  'www.tandlaegehusetharlev.dk',
#  'Du kan se mere om os på www.garner.dk . Ring gerne helt uforpligtende på 40 95 51 33 . Det er vigtigt for os at finde den rette profil til vores "klinik familie", så vi kan vente på den rette.',
#  '40955133: Ansøgningsfrist',
#  'jeanette@garner.dk: Website',
#  'www.garner.dk: Se også',
#  'Mærk din ansøgning " Digital elev " og send din ansøgning til :bm@damkjaersko.dk',
#  'Ansøgning og CV sendes asap til: fratellipizza81@gmail.com',
#  'Har dette fanget din interesse, så send gerne din ansøgning til job@helm.nu.',
#  'Har du spørgsmål til jobbet, kan du kontakte Elsebeth på tlf. 31160190.',
#  'Bostøttemedarbejdere søges pr. 1. april 2024 eller efter aftale.',
#  'Tiltrædelse den 1. april 2024 eller efter aftale.',
#  'Du bedes sende din ansøgning senest den 20. februar 2024 kl. 12.',
#  'Leder - Jeanett Kuldborg tlf. 4452 7172 (ferie 9.– 21.februar).',
#  'Funktionsleder Voksensociale Tilbud - Kirsten Breinholt tlf. 2495 2748.',
#  'Jeg har en god mavefornemmelse, når jeg møder på job om morgenen ". Kontakt og ansøgning Ansættelses samtaler løbende Hvis du vil høre mere om stillingen, er du velkommen til at kontakte teamleder Theresa Larsen på tlf.: 56 67 65 70 .',
#  'Stillingen er en fast stilling på 30 timer og til besættelse den 1. april 2024 eller snarest.',
#  'Ansøgningsfrist den 25. februar 2024',
#  'Samtaler forventes afholdt onsdag den 28. februar 2024.',
#  'Ansøgning (med vellignende billede af ansøger) bedes sendt til job@ne-partner.dk',
#  'Har du spørgsmål til jobbet, er du velkommen til at kontakte Malene Carlsen på: mca@oliviadanmark.dk',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte teamleder for Økonomi og Hushold, Ida Pedersen på 52 17 45 47 eller afdelingsleder for Økonomi, Match og Familieplejen Jonas Faarvang på 40 32 91 94.',
#  'Ansøgningsfrist er den 19. februar 2024. Vi forventer at afholde samtaler den 26. februar 2024.',
#  'Har du spørgsmål er du velkommen til at kontakte direktør Jesper Nørgaard 2014 7813 eller via mail på jgn@skabertrang.dk',
#  'Kontaktperson: Ansøgning sendes pr mail til nv@tekniclean.dk',
#  'For more information or questions please contact us at morten@unbelievablelabs.com or phone number 24261018',
#  'Hvis jobbet lyder som noget for dig, så send en kort ansøgning og dit CV på mail til job@sengetid.dk.',
#  'Du er også velkommen til at ringe til Head of Office Allan Jørgensen på 60 60 64 47.',
#  'Læs mere om Det Kongelige Akademi på vores hjemmeside www.kglakademi.dk.',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte Aksel Uglvig Jensen, Skelmose, på tlf. 40 84 01 33.',
#  'www.elektro-isola.dk',
#  'Tlf. +45 40 84 01 33',
#  'E-mail: auj@skelmose.eu',
#  'Stillingen besættes efter protokollat af 23. maj 2019 til overenskomst for akademikere i staten om officerer under Forsvarsministeriet.',
#  'Hvis du vil vide mere om stillingen, er du velkommen til at kontakte Niels Klingenberg Vistisen, Forsvarsministeriets Personalestyrelse på telefon 7281 9622',
#  'Hvis du har spørgsmål til løn eller ansættelsesvilkår, kan du kontakte HR-Konsulent kaptajn Thomas Søren Eskebjerg Krog, Forsvarsministeriets Personalestyrelse på telefon 7281 9159.',
#  'Ansøgningsfristen er den 6. februar 2024 og vi forventer at holde samtaler løbende.',
#  'Læs mere om Forsvaret som arbejdsplads på www.Forsvaret.dk',
#  'ibn@jobteam.dk',
#  '24 29 27 97',
#  'udgivet 2 februar 2024: referencenr.11078',
#  'Såfremt du ønsker at vide mere om stillingen, er du velkommen til at kontakte Randstad, teamleder Lotte Kristoffersen på tlf. +45 2152 4828. Alle henvendelser behandles fortroligt.',
#  'udgivet 2 februar 2024: referencenr.11082',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte seniorkonsulent Dorte Poulsen på tlf. 92921198. Der vil blive holdt samtaler løbende.',
#  'Kontakta affärsområdeschef, Johan Jönsson, på mail jjn@le34.se eller tel.',
#  '+46 (0)769-410 530 eller VD Mickael Holgersson, på mail mic@le34.se eller +46(0)709703090.',
#  'Vi søger en ny kollega til vores a-kasse, med tiltrædelse den 1. april 2024.',
#  'Ansøgning Send din ansøgning til aalborg@3f.dk, skriv " A-kassemedarbejder" i emnefeltet, så vi har den senest den 16. februar kl. 17.00.',
#  'Vi afholder ansættelsessamtaler d. 19. februar.',
#  'Vil du vide mere: Har du spørgsmål, er du velkommen til at kontakte A-kasseleder Dan Oxholm på telefon 40577190, mail: dan.oxholm@3f.dk eller souschef i a-kassen, Søren Nellemann Johansen, telefon 23319731, mail soren.johansen@3f.dk Søg stillingen',
#  'Nærmere oplysning om stillingen kan fås hos Formand Torben Knudsen på telefon 70300814.',
#  'Hvis du har lyst til at blive en del af vores faglige team og arbejde sammen med gode kollegaer, så send din ansøgning til sekretær Ulrik Haslev: ulrik.haslev@3f.dk senest de n 14. februar 2024 kl. 9.00.',
#  'Der vil blive afholdt samtaler mandag den 19. februar 2024.',
#  'Yderligere oplysninger om stillingen kan fås ved henvendelse til Leder Anne Ringsted Jacobsen på 51575044 eller anrija@aarhus.dk',
#  'Du er velkommen til at kontakte Uddeler Flemming Brasen (ferie uge 6) på telefon 3324 4030 – eller kig forbi butikken til en snak.',
#  'Send din ansøgning via "Ansøg nu" senest den 18 Februar 2024',
#  'Du kan læse mere om, hvordan det er at arbejde hos Clever på: www.clever.dk/velkommen',
#  'Du kan sende din ansøgning via "Søg job" senest den 2. marts 2024',
#  'Din ansøgning vil efter d. 2. april 2024 blive slettet fra vores system.',
#  'For yderligere informationer om job og ansættelsesvilkår er du velkommen til at kontakte HR Partner Vibeke Nedergaard via e-mail: vibeke.nedergaard@coop.dk',
#  'Du er velkommen til at kontakte Uddeler Simon Jensen på telefon 47383073 – eller kom forbi med din ansøgning.',
#  'Send din ansøgning via "Ansøg nu" senest den 07. Februar 2024.',
#  'All applicants must always apply for positions via our website: https://job.experis.dk.',
#  'Head of HR Rikke Alkert +45 96 20 70 40 · [email protected]',
#  'HR Consultant Cæcilie Sams +45 29 62 72 18 · [email protected]',
#  'HR Coordinator Marcus Kaas +45 31 31 46 51 · [email protected]',
#  'HR Coordinator (on maternity leave) Anna Louise Brandt Andersen +45 20 35 52 38 · [email protected]',
#  'Global Talent Acquisition Manager Johnni Krogh +45 30 52 21 07 · [email protected]',
#  'Du er velkommen til at kontakte Privatkundechef, Mette Lund Raagart på tlf. 72 25 01 75 hvis du vil vide mere om jobbet.',
#  'Ansøgningsfristen er den 19. februar 2024, men søg gerne allerede nu, da vi løbende vil holde samtaler.',
#  'https://www.sparnord.dk/',
#  'Har du spørgsmål til stillingen er du velkommen til at kontakte Indkøbschef Thomas Archard Jensen 2525 7125 eller via mail thomas.jensen@bravida.dk.',
#  'www.bravida.dk',
#  'https://www.bravida.dk/job-i-bravida/ledige-job/?rmpage=job&rmjob=8940&rmlang=DK',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte Lars Skjøth på 60134544.',
#  'https://lsb.dk',
#  'Så er du meget velkommen til at kontakte afdelingschef Peter Steen Kristensen på tlf. 20 40 60 67 / pk@menzerkristensen.dk',
#  'Publiceret 4. januar 2024',
#  'Kontakt Peter Steen Kristensen pk@menzerkristensen.dk 20 40 60 67',
#  'Du kan kontakte Salgschef Claus Koch på tlf. 61 61 01 80 eller besøge os på vores hjemmeside.',
#  "I 2022 omsatte Inwido for 9,5 milliarder SEK og havde en operationel EBITA-margin på 11,4%. Inwido har været noteret på Nasdaq Stockholm siden 2014. Du kan følge Inwido's rejse her LinkedIn og www.inwido.com.",
#  'Hvis du vil vide mere om uddannelsen er du velkommen til at kontakte elevansvarlig Erik Pihl Aalstrup, mobil 40199063 eller på mail eaalestrup@grundfos.com.',
#  'Hvis du har spørgsmål til stillingen, er du velkommen til at kontakte Manager for IAM, Christian de Lichtenberg på 63639123, eller Service Arkitekt og Scrum Master, Lene Rewitz Søndergaard på 63639062.',
#  'på www.fisker.as.',
#  'Eller, se videoer fra vores YouTube-kanal: https://www.youtube.com/channel/UC3rHZguJ7JU3LlNSgSu2xIg',
#  'Vil du vide mere om stillingen, er du velkommen til at kontakte chef for teknisk afdeling, Mikkel Søe, på tlf. 2069 1884 eller mst@fisker.as',
#  'Er stillingen noget for dig, så send ansøgning med CV til mst@fisker.as snarest muligt.',
#  'Please contact Head of UX UI Design Platform, Dripta Guha Roy at +4553194745',
#  'Vi søger elever over hele landet med opstart august 2024.',
#  'Har du spørgsmål til stillingen, er du velkommen til at sende en mail til jalu@ilva.dk.',
#  'August 2024',
#  'Har du spørgsmål til jobbet, kan du kontakte rekrutteringskonsulenter hos HR navigator Jens Jensen på +45 22 69 79 84. Tiltrædelse er snarest muligt, men vi venter naturligvis på den rigtige kandidat.',
#  'Sinnerup Holstebro , Sinnerup Publiceret 29. januar 2024',
#  'Ansøgningsfrist 1. marts 2024',
#  'Hvis du har spørgsmål, så kontakt Laura Bering på LSB@sinnerup.com',
#  'Har du spørgsmål til jobbet, kan du kontakte Customer Service Manager, Sofie Agger Hamidovic på sa@sixt.dk',
#  'Bliv social- og sundhedshjælperelev med start fra august 2024',
#  'Pleje & Omsorg i Skive Kommune søger elever til social- og sundhedshjælperuddannelsen med start 1. august 2024.',
#  'Du kan få yderligere informationer om stillingen ved at kontakte uddannelseskonsulent Dorte Søgaard på mail doso@skivekommune.dk eller på telefon 24 83 76 02.',
#  '5. maj 2024',
#  '1. august 2024',
#  'Tlf. 24837602',
#  'Vi er fra 1.februar 2024, 7 speciallæger, heraf 2 stillinger som delestillinger med Rigshospitalet.',
#  'Har du lyst til at høre mere om stillingen, og de muligheder, som ligger i jobbet, så kontakt Cheflæge Lene Marie Isaksen, 93576410, leisa@regionsjaelland.dk eller overlæge Mette Grove metg@regionsjaelland.dk',
#  '29. januar 2024',
#  '26. februar 2024',
#  'Hvis du vil vide mere , kan du læse mere på www.rk.dk . Du er også velkommen til at kontakte Leder, Marianne Telling, mail cn29707@rk.dk, tlf. 30768089.',
#  'Vi skal have din ansøgning med relevante bilag og referencer senest den 5. februar 2024 . Klik på knappen "søg job" for at sende din ansøgning.',
#  'I januar 2025 står der et helt nybygget børnehus parat til os i forbindelse med skolen.',
#  'Søndag den 31. marts 2024',
#  'Ansættelse pr. 1. april 2024 eller hurtigst muligt',
#  'Telefon til børnehuset 87 94 20 80. Ring gerne og få en snak eller aftal en rundvisning.',
#  '31. marts 2024',
#  'Du er velkommen til at henvende dig til Ældrecenterleder Yvonne Pedersen på telefon 99 88 85 45 eller pr. mail iyvpe@rebild.dk',
#  '16. februar 2024 kl. 12.00.',
#  'Den 1. januar 2019 blev der indført røgfri arbejdstid – og matrikler for alle ansatte i Rebild Kommune',
#  'Tlf. 99888545',
#  'Så send din ansøgning og CV til Job@sundplejen.dk Ansøg gerne hurtigst muligt.',
#  'Har du spørgsmål, er du velkommen til at kontakte Rikke Skovbjerg på telefon 22 97 97 15',
#  'Lyder ovenstående som noget for dig, så send din ansøgning til christina@sundtakeaway.dk med en motiveret ansøgning med Køkkenmedhjælper i emnefeltet.',
#  'Samtaler afholdes løbende, og såfremt du ikke hørt fra os inden 29. februar, er stillingen besat til anden side.',
#  'Slagtermester Dennis Iversen tlf. 65381155',
#  'Ansættelsesstart 1. april 2024 eller efter aftale.',
#  'Send din ansøgning via "Ansøg nu" senest den 18. februar 2024',
#  '[Souschef] [Martin Larsen tlf. 3826 2310',
#  'Send din ansøgning via "Ansøg nu" senest den 16. Februar 2024.',
#  'For mere information er du velkommen til at ringe til Uddeler Martin Halle tlf. 9894 1722.',
#  'Du sender din ansøgning via "Ansøg nu" senest den 3 Marts 2024.',
#  'Slagtermester Morten Thomsen på tlf. 86290500/50922296 - kig gerne forbi til en uformel snak.',
#  'Kontakt Slagtermester Morten Thomsen på tlf. 86290500/50922296 - kig gerne forbi til en uformel snak',
#  'Du kan sende din ansøgning via "Ansøg nu" senest den 29. februar 2024',
#  'Du er velkommen til at kontakte Uddeler Nicolai Damsgaard på telefon 4247 0108 – eller kig forbi butikken til en snak.',
#  'Send din ansøgning via "Ansøg nu" senest den 29. Februar 2024',
#  'Hvis du vil vide mere om stillingen eller Sweco som arbejdsplads, kan du kontakte teamchef Steffen Salbo på tlf.: +45 4282 1325 mail steffen.salbo@sweco.dk.',
#  'Brug linket for at sende din ansøgning og CV med relevante dokumenter i dag eller senest d. 18. februar 2024. Vi modtager ikke ansøgninger på mail.',
#  'https://syddjurs.emply.net/recruitment/vacancyAd.aspx?publishingId=573d0a7d-4efa-4934-9658-bf5427fbf7dc',
#  'Hjemmeside syddjurs.emply.net/recruitment/vacancyAd.aspx?publishingId=573d0a7d-4efa-4934-9658-bf5427fbf7dc Telefonnr. 20532229 E-mail jmduj@syddjurs.dk Kontaktperson Julie Maria Duval Jensen',
#  'Vi hører meget gerne fra dig og håber, at kunne byde dig velkommen på Søndermarksskolen senest den 1. april 2024',
#  'Vi skal have din ansøgning senest den 22. februar 2024',
#  'Vi afholder ansættelsessamtaler den 26. februar fra kl. 14.30',
#  'Helle Meisner, afdelingsleder 20 84 69 06 og Lone Villemoes, skoleleder 24 98 97 29',
#  'Du kan læse mere om os på https://soendermarksskolen-vejle.aula.dk',
#  'Se mere på www.vejle.dk/tilflytter.',
#  'Send gerne en kort ansøgning og CV til HR Chef, Joachim på joachim@rbbusiness.dk eller ring på tlf. 93 96 03 42 hvis du har spørgsmål til jobbet.',
#  'Du er velkommen til at kontakte journalist Sophie Hansen per e-mail kontakt@radiolorry.dk, hvis du vil vide mere om jobbet.',
#  'Ansøgningsfristen er den 12. februar 2024 kl. 23.59. Send motiveret ansøgning og CV på mail: kontakt@radiolorry.dk Vi forventer at holde samtaler i starten af uge 8.',
#  'Har du spørgsmål eller brug for yderligere information om stillingen, er du mere end velkommen til at kontakte uddannelseskonsulent Bente Juulsgaard telefon 89 15 19 51 eller administrativ medarbejder Henny Bidstrup telefon 89 15 18 73.',
#  'Du kan finde mere information om uddannelsen på http://www.sosuiranders.dk',
#  'Ansøgning skal sendes via Randers Kommunes hjemmeside senest 25. februar 2024. Vi forventer at afholde samtaler den 4. marts 2024.',
#  '2 barselsvikariater frem til 31. januar 2025, med mulighed for forlængelse.',
#  'om stillingen kan fås ved henvendelse til distriktsleder Line Juhl på telefon 24 96 60 83.',
#  '13. marts 2024, og der afholdes løbende samtaler.',
#  'Hos Redmark søger vi en dygtig HR-konsulent til vores kontor i Aalborg, der skal dække et barselsvikariat på 10 måneder med start senest den 1. april 2024.',
#  'Vil du vide mere om stillingen, er du velkommen til at kontakte HR Senior Associate Trine Lindholm på +45 41 86 56 67 eller HR Chef Marlene Krogh på +45 41 86 56 61. Rekrutteringsprocessen kører løbende og stopper, når vi har mødt den helt rigtige ...',
#  '29. februar 2024',
#  'Vi søger 2 sygeplejersker til Lungemedicinsk Afdeling, Aalborg Universitetshospital pr. 1. marts 2024 eller efter aftale.',
#  'Forhåbentlig har ovenstående fanget din interesse, så booke tid til en samtale på 97660818',
#  'Ansøgningsfrist d. 26. februar 2024',
#  'Så kan du kontakte Chefsygeplejerske Inge Smed på tlf. 97664780 eller konst.',
#  'Klinisk Afsnitskoordinator Trine Thomsen, på tlf. 97664781.',
#  'Læs mere om os på www.rn.dk.',
#  'Du kan læse mere om Solsiden på www.solsiden.dk',
#  'Der er ansøgningsfrist den 4. februar 2024. Vi afholder løbende samtaler.',
#  'Har du spørgsmål må du gerne kontakte tilbudsleder Gitte Vejby, telefon 29382278 mellem 8.00 og 15.00 på hverdage.',
#  '2 stillinger er ledige til besættelse fra 1. april 2024.',
#  'Ansøger bedes i ansøgningen - med bedst mulig dokumentation - forholde sig konkret til de syv lægeroller jævnfør Sundhedsstyrelsens rapport: De syv lægeroller, fra maj 2013',
#  'Ledende Overlæge Shideh Pour Zahed, shpo@regionsjaelland.dk, mob.23415929',
#  '19. februar 2024',
#  'Den 1. januar 2024 fusionerede Sjællands Universitetshospital (SUH) med Nykøbing F. Sygehus (NFS). Som et af Danmarks største akutsygehuse driver og udvikler vi sygehusene i Køge, Roskilde og Nykøbing F. Vi har aktivitet på alle regionens sygehuse, og ...',
#  'Platangårdens Ungdomscenter søger en ernæringsassistentelev til vores kantine 1. marts 2024.',
#  'Hvis du er interesseret i at vide mere om Platangården, kan du gå ind på www.platangaarden.dk.',
#  'https://www.regionsjaelland.dk/job-og-uddannelse/jobside?hr=show-job/40458&locale=da_DK&sd=1',
#  'Hjemmeside www.platangaarden.dk.',
#  'Telefonnr. 55350300 E-mail platangaarden@regionsjaelland.dk Kontaktperson Line Petersen',
#  'Yderligere oplysninger fås hos ledende overlæge Anja Bate, ajah@regionsjaelland.dk eller',
#  'cheflæge Ditte Erngaard, der@regionsjaelland.dk ,',
#  'Du kan læse mere om Sjællands Universitetshospital på www.regionsjaelland.dk og mere om Øjenafdelingen på her .',
#  'Ansøgningsfrist 14. februar 2024',
#  '14. februar 2024',
#  '56515118, lmjn@regionsjaelland.dk',
#  '15. februar 2024',
#  '1. marts 2024',
#  'Du kan høre mere om stillingen ved at kontakte chefsygeplejerske Mette Aronsson Thornbjerg, mobil 2334 9957.',
#  'Funktionsbeskrivelse kan rekvireres hos afdelingsledelsessekretær Signe Vendelbo Lektonen tlf.: 4732 3572 eller mail: slek@regionsjaelland.dk',
#  'Ansøgningsfrist: 7. februar 2024',
#  'Yderligere oplysninger kan fås ved henvendelse til serviceleder Lone Nielsen (tlf.: 7842 7406)',
#  'Ansøgningsfrist er d. 15. februar 2024 via nedenstående link',
#  'Telefon: 78427406',
#  'Vi holder samtaler onsdag 6. marts 2024, bemærk der er opslået 2 stillinger på henholdsvis 25 og 32 timer.',
#  '25. februar 2024',
#  '1. maj 2024',
#  'Hvis du vil vide mere om stillingen, er du meget velkommen til at kontakte seniorsergent Ib S. Larsen; 72 81 61 25.',
#  'Har du spørgsmål til løn- og ansættelsesvilkår, kan du kontakte HR-konsulent John K. Christiansen ved Forsvarsministeriets Personalestyrelse på tlf. 72 81 93 20.',
#  'Ansøgningsfrist er den 17. marts 2024 og samtaler forventes afholdt umiddelbart herefter.',
#  'mail@broagerprivateboernehus.dk',
#  'Bagermester, Michael Jakobsen tlf. 5819 4013',
#  'Send din ansøgning senest den 24. februar 2024',
#  '2. januar 2024',
#  'Annette Foltmann, mail af@spia.dk',
#  'Peter Ring, tlf. 22 20 90 40, mail peter@spia.dk',
#  'Såfremt stillingen har din interesse, er du velkommen til at tage kontakt for uddybende oplysninger om stillingen og tilhørende arbejdsopgaver til Leder Tanja Møller, tlf. +299 367666 eller e-mail: tjml @sermersooq.gl',
#  'For yderligere information om husleje herunder forbrug o.l. henvises til oplysninger på : www.iserit.gl',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakt Country Director, Ralph Gonsalves på 2497 8063',
#  'Publiceret 29. januar 2024',
#  'Ansøgningsfrist 26. februar 2024',
#  'Kontakt Country Director, Ralph Gonsalves 24978063',
#  'Vi forventer at kigge på indkomne ansøgninger igennem løbende, så send hurtigst muligt din ansøgning og allersenest d. 14. februar 2024',
#  'Har du spørgsmål til rollen kan du kontakte Christian Bork ved at sende en mail på cbandersen@nilfisk.com .',
#  'Vi forventer at kigge på indkomne ansøgninger efter 14. februar 2024.',
#  'Send ansøgning + CV og eventuelle samples på dit arbejde til michael@nordictipi.dk.',
#  'Har du spørgsmål, kontakt os da via samme mail eller +45 30565852.',
#  'Vil du vide mere om stillingen, er du velkommen til at kontakte afdelingsleder Tonny Rokkjer Hansen på +45 3079 3662.',
#  '4. februar 2024',
#  'Vil du vide mere om stillingen, er du meget velkommen til at kontakte ansættende chef Bettina Dyring på tlf.: 3075 9014.',
#  '15 februar 2024 – ansøgninger behandles løbende, så send gerne din snarest.',
#  'Vil du vide mere om stillingen, er du velkommen til at kontakte Christian Holen Møller, Associate Manager, på mobil + 45 30 79 87 48.',
#  'For further information, please contact Automation Director Gavin Michael Jarus on the phone at +45 34 48 62 94.',
#  'Apply before February, 25 2024.',
#  'Ansøgningsfristen er 29. februar 2024.',
#  'For yderligere information om stillingen, kontakt Ecommerce Director Rasmus Thau Høgsted-Riddersholm, rashog@yousee.dk.',
#  'Ansøgningsfrist : 29 februar 2024',
#  'Kontaktperson: Ecommerce Director Rasmus Thau Høgsted-Riddersholm, rashog@yousee.dk.',
#  'Læs mere om, hvordan vi behandler dine personoplysninger her: https://nuuday.dk/karriere',
#  'Ansøgningsfrist : 11 februar 2024',
#  'Kontaktperson: Rie Michaela Gude Jensen på RIEJE@yousee.dk',
#  'Vi forestiller os, at du stater dit 2-årige uddannelsesforløb hos os omkring 15. august 2024, men er selvfølgelig fleksible i forhold til et andet starttidspunkt, der eventuelt måtte passe dig bedre.',
#  'Du er velkommen til at kontakte Dorthe Hoffmann Atzen på (+45) 27 77 75 71, hvis du har spørgsmål til elevpladsen.',
#  'Søg elevpladsen gennem dette link: https://pressalit.easycruit.com/vacancy/3265591/76043?iso=dk',
#  'Hjemmeside pressalit.easycruit.com/vacancy/3265591/76043?iso=dk Telefonnr. 27583568 E-mail ang@pressalit.com Kontaktperson Anna Nørregaard Gramstrup',
#  'Tiltrædelse 1. april.',
#  'Ansøgning samt CV sendes til: hr@procopa.dk',
#  'så kontakt Daniel på 23393497.',
#  'tlf. (+45) 70 70 12 30.',
#  'Du er velkommen til at kontakte arbejdstidsplanlægger Birgitte Maxwell på tlf.: 3199 0106 eller assisterende leder Trine Roedahl Gaul på tlf.: 2520 0938',
#  'Trine Roedahl Gaul +4525200938',
#  'Så er du måske vores nye ungarbejder i kassen til den spritnye Plantorama Kolding, som vi slår dørene op til i marts 2024.',
#  'https://www.plantorama.dk/',
#  'Kommuneqarfik Sermersooq søger en dygtig og engageret vagthavende livredder til svømmehallen MALIK med tiltrædelse 01. oktober 2019 eller snarest derefter.',
#  'Du kan finde flere oplysninger om os på: www.malik-nuuk.gl eller via www.sermersooq.gl',
#  'Såfremt stillingen har din interesse, er du velkommen til at tage kontakt for uddybende oplysninger om stillingen og tilhørende arbejdsopgaver til Cafeansvarlig Carla Villadsen, tlf. +299 36 63 14 eller e-mail: cavi @sermersooq.gl',
#  'Ansøgningsfrist: 8. februar 2024',
#  'Vi søger en kontorelev med speciale i administration til ansættelse per 1. marts 2024 eller snarest herefter.',
#  'Har du nogen spørgsmål, er du velkommen til at kontakte Antonella på +45 7060 4626. Vi glæder os til at modtage din ansøgning, som kan sendes til antonella@profsyn.dk.',
#  'Hjemmeside profsyn.dk/ Telefonnr. 70604626 E-mail Antonella@profsyn.dk Kontaktperson Antonella Olsen',
#  'Slagtermester Claus Møller Pedersen på tlf. 86156733',
#  'Send din ansøgning via "Ansøg nu" senest den 27. februar 2024.',
#  'https://duos.dk/cookies/ token Nødvendig DUOS A/S Session Sørger for vi ved hvilken type bruger du er (borger, hjælper osv.) https://duos.dk/cookies/ availableRoles Nødvendig DUOS A/S Session Sørger for vi ved hvilken type bruger du er (borger, ...',
#  'https://duos.dk/cookies/ hasAllowedNecessaryCookies Nødvendig DUOS A/S 1 år Husker dit valg om statistik cookies.',
#  'https://duos.dk/cookies/ hasAllowedTrackingCookies Statistisk Microsoft Session Bruges til monitorering af fejl https://privacy.microsoft.com/da-dk/privacystatement AI_Buffer',
#  'Ansøgning sendes til hr@kbs.dk.',
#  'Sidste frist for ansøgninger er den 15. februar 2024.',
#  'Ansættelsessamtaler afholdes den 20. februar og 2. samtale afholdes den 22./23. februar 2024.',
#  'Tiltrædelse 1. april 2024.',
#  'Ønskes yderligere oplysninger kan områdeleder Karl-Åge træffes på tlf. 30431670.',
#  'Eller læs mere om KBS på www.kbs.dk.',
#  'Når du ansøger om stillingen, accepterer du samtidig vores behandling af personoplysninger i rekrutteringsprocessen, som du kan læse her: https://kbs.dk/wp-content/uploads/Persondata/073-Behandling-af-oplysninger-ifm-ansøgning-om-ansættelse-i-KBS.pdf',
#  'Vi søger en pædagog på 35 timer til vores SFO fra 1. marts.',
#  'Stillingen er med fastansættelse på 35 timer fra 1. marts 2024. Løn - og ansættelsesvilkår sker i henhold til gældende overenskomst mellem BUPL og KL.',
#  'Ansøgningsfrist fredag d.16. februar 2024 kl.12.00',
#  'Samtaler afholdes tirsdag d. 27. februar Formiddag.',
#  'Du er velkommen til at kontakte SFO leder Maria Strange på tlf. 20300175 for at høre nærmere om stillingen.',
#  '16. februar 2024',
#  'Den 1. januar 2019 slog vi dørene op til et helt nyt demensplejecenter i den nordlige del af Køge Kommune.',
#  'Hvis du har spørgsmål til stillingen, er du velkommen til at kontakte Desiree Petersen på tlf. 40327861',
#  'Vi forventer at holde samtaler d.26.2.24 og med tiltrædelse 1. april 2024',
#  'Læs mere om Køge Kommune på www.koege.dk',
#  '20. februar 2024',
#  '21. februar 2024',
#  'Ansøgningsfristen er onsdag d. 14. februar 2024. Vi holder samtaler løbende.',
#  'Har du spørgsmål til stillingen, er du meget velkommen til at kontakte afdelingsleder Marc Somers på tlf. 4029 6191 - marcomhs@roskilde.dk eller afdelingsleder Ditte Elgaard Hansen på tlf. 3084 1435 - ditteeh@roskilde.dk',
#  'Vi søger en lærer med en relationskompetent profil til vores specialklasser til en 37 timers stilling i vores gruppeordning "Vækstklassen" på Lynghøjskolen fra d. 1. april 2024 eller før.',
#  'Viceskoleleder, Helle Baktoft, tlf. 4631 4312 eller mail: helleb@roskilde.dk',
#  'Skoleleder, Martin Heramb, tlf. 4631 4311 eller mail: martinhe@roskilde.dk',
#  'Stillingen er til besættelse pr. 1. april 2024.',
#  'Ansøgningsfristen er d. 25. februar 2024, kl. 15.',
#  'Samtaler forventes afholdt d. 27. februar 2024 efter kl. 13.',
#  'Ansøgningsfristen er den 19. februar 2024, og vi ser gerne at du kan starte op i jobbet d. 1. marts 2024.',
#  'Tiltrædelse i jobbet vil være d. 1. september 2024.',
#  '1. september 2024',
#  'Beredeskabsstyrelsens officersuddannelse har siden 1. januar 2020 været etableret i et samarbejde med Forsvarsakademiet og værnenes officers- og sergentskoler, herunder især Flyvevåbnets Officersskole.',
#  'Du kan få yderligere oplysninger om stillingen ved at kontakte brigadechef, Martin Vendelbo på telefon 41 62 20 75, eller sektionschef Martin Vang Nielsen på telefon 22 82 02 40.',
#  'Har du spørgsmål til løn og ansættelsesvilkår, kan du kontakte Forsvarsministeriets Personalestyrelse, HR-konsulent kaptajn Thomas Gjøll Hansen på telefon 32 66 59 08 eller på mail: FPS-THH@fiin.dk',
#  'Ansøgningsfristen er d. 15. februar 2024. Samtaler forventes afholdt snarest derefter',
#  'Dameafdelingen søger en elev til opstart d. 1. august 2024.',
#  'For yderligere information kontakt Butikschef Kristine Göhns Sørensen på tlf. 63109931.',
#  'Ansøgning sendes til job.dd@nielsens.dk',
#  'Hjemmeside Nielsens.dk/ Telefonnr. 63109931 E-mail job.dd@nielsens.dk Kontaktperson Kristine Göhns Sørensen',
#  'Kommuneqarfik Sermersooq søger en dygtig og engageret AC-fuldmægtig til Forvaltning for Børn og Skole med tiltrædelse 1. marts 2024 eller efter aftale.',
#  'Flere oplysninger om kommunen findes på: https://sermersooq.gl/da',
#  'Såfremt stillingen har din interesse, er du velkommen til at tage kontakt for uddybende oplysninger om stillingen og tilhørende arbejdsopgaver til Stabschef Charlotte Bech, tlf. +299 367321 mobil: 537921 eller e-mail: chbe@sermersooq.gl',
#  'Såfremt stillingen har din interesse, er du velkommen til at tage kontakt for uddybende oplysninger om stillingen og tilhørende arbejdsopgaver til Kommunikationschef Lars Damklær, tlf. +299 36 75 11 eller e-mail: lada@sermersooq.gl',
#  'Hvis du kan se dig ind i ovenstående, skal din ansøgning sendes afsted senest søndag den 18. februar.',
#  'Vi forventer at afholde samtaler den 27. februar og evt. 2. samtale den 28. februar.',
#  'Tiltrædelse pr. 1. april.',
#  'eller spørgsmål vedr. stillingen er du velkommen til at kontakte faglig koordinator Kristian Munk, mail: kpm @jammerbugt.dk / mobil 41 91 37 93 eller afdelingsleder Signe Horsager, mail: sgh@jammerbugt.dk / mobil 41 91 26 86.',
#  'Tlf. 41913793',
#  'Deputy Store Manager til JYSK Silkeborg: Telefonnummer: +45 72 18 41 70',
#  'Elev til Tønder: Telefonnummer: +45 72 18 44 40',
#  'Sælger til JYSK Vejen - Tidsbegrænset: Telefonnummer: +45 72 18 46 70',
#  'Af Tina Svenningsen 29. January 2024',
#  'Send din ansøgning til job@jaconnect.dk, mærket: "Servicetekniker"',
#  'Er du velkommen til at kontakte Jørn Aas 54556611',
#  'If you meet the above qualifications and are enthusiastic about contributing to the promotion of Korean trade in Denmark, we encourage you to apply by Feb 16. Please submit your resume and cover letter to info@kotra.dk.',
#  'Vi står bag www.cateringinventar.dk, www.restaurantinventar.dk, www.ostergaard-i.dk www.wallshop.dk, www.gastrobutikken.dk, www.knivblokken.dk, www.storkoksbutiken.se mf.',
#  'Kpa Company ApS, Rømersvej 33, 7430 Ikast, job@cateringinventar.dk',
#  'Stillingen er med en ugentlig arbejdstid på 37 timer, og vi forventer at besætte stillingen fra den 1. april 2024 eller hurtigst muligt.',
#  'Hvis du vil vide mere om stillingen, er du velkommen til at kontakte leder af tværfagligt udviklings- og kompetenceteam Stine Matzen telefon 42 74 2929 eller leder af Familie, Børn og Ungerådgivningen Youssef Bibi telefon 23 28 92 86 / mail ybx@ ...',
#  'Vi afholder ansættelsessamtaler tirsdag den 27. februar 2024 fra kl. 12:00. Kandidater som kommer i betragtning vil få invitation til samtalerne fredag d. 23. feb.',
#  'Stillingen er til besættelse d. 1. april 2024',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte faglig leder af Familieteamet Anna Carlsen på mail.: abca@kerteminde.dk',
#  'Du kan sende din ansøgning til job@jaconnect.dk mærket: "Montør medhjælper".',
#  'Send din ansøgning til job@jaconnect.dk, mærket "Montør varmepumper"',
#  'Har du spørgsmål til stillingen, er du velkommen til at kontakte Jørn Aas på 5455 6611',
#  'Slagtermester Mike Fritzen på tlf. 28296042',
#  'Send din ansøgning via "Ansøg nu" senest den 26. Februar 2024.',
#  'Hvis du går rundt med en lille drøm i maven om at kunne fremtrylle lækre delikatesser, så send din ansøgning via "Ansøg nu" senest den 28. februar 2024.',
#  'Du kan også kigge forbi Kvickly Åbyhøj og tage en snak med Slagtermester Claus Pedersen eller ringe på 29797692',
#  'Hvis du går rundt med en lille drøm i maven om at blive god til at skære en bøf perfekt, så send din ansøgning via "Ansøg nu" senest den 28. februar 2024.',
#  'Du kan også kigge forbi Kvickly Åbyhøj og tage en snak med slagtermester Claus Pedersen eller ringe på 26797692',
#  'Værkstedschef Kent Hviid på kehv@viabiler.dk eller tlf. 87 22 10 16',
#  'Pladeværkfører Peder Boldsen på pebo@viabiler.dk eller tlf. 87 20 65 87',
#  'Publiceret 2. februar 2024',
#  'Kontakt Kent Hviid kehv@viabiler.dk 87 22 10 16',
#  'https://dentist.dk/alle-klinikker/toender/: Se også',
#  'https://dentist.dk/alle-klinikker/toender/',
#  'Vi glæder os til at høre fra dig, og modtager din ansøgning og cv på job@dentist.dk eller ring til Majbritt allerede i dag og hør nærmere på 20 77 32 66. Kontakt Dentist.dk',
#  'www.dentist.dk: Se også',
#  'www.dentist.dk',
#  'Vi ser frem til at modtage din ansøgning og CV på job@dentist.dk eller ringe til Majbritt allerede i dag og hør nærmere på 20 77 32 66.',
#  'https://dentist.dk/alle-klinikker/egtved/: Se også',
#  'https://dentist.dk/alle-klinikker/egtved/',
#  'Er det noget for dig, så har vi 1 fast stilling og 2 barselsvikariater ledige pr. 1. april 2024 eller efter aftale.',
#  'tlf. 2790 7074 eller daglig leder Christina Kostelac 2790 7073',
#  'Ansøgningsfrist: søndag den 25. februar 2024.',
#  'Samtaler afholdes: tirsdag den 27. februar 2024.',
#  'Tiltrædelse pr. 1 april eller efter aftale.',
#  'Har du brug for yderligere oplysninger så ring til Gråsten Plejecenter, Kontakt Tina Kock på tlf.: 92 43 46 78 eller Bente Kaehne på tlf.: 21 41 70 54',
#  'Send en ansøgning til Job@jaconnect.dk, mærket: "Elektriker Titech"',
#  'Hvis du har spørgsmål til stillingen, er du velkomment til at kontakte Lene Venø på 5455 2411',
#  '12. februar 2024',
#  'Ansøgningsfristen er d.12.februar, hvor vi indkalder til samtaler efterfølgende.',
#  '1. april eller efter aftale',
#  'Opstart gerne 1 april, og ellers efter aftale med dig.',
#  '+45 26 66 15 83',
#  'Såfremt ovenstående har din interesse, så send din ansøgning til jabj@tennberg.dk snarest muligt.',
#  'Hvis ikke du har hørt fra os senest den 06. februar, så er stillingen besat til anden side.',
#  '| Privacy | Terms of Use | Fraud Alert | Tracking Consent | Teradata is an Equal Opportunity Employer | www.teradata.com',
#  'enten tlf.: 88779737, eller mail: info@thycablepark.dk',
#  '30 timer om ugen, 1. april 2024 (eller marts hvis mulig) til 31. oktober 2024',
#  'Ansøgningen sendes til info@thycablepark.dk , titel "jobansøgning", senest den 05. februar 2024, kl 8:00',
# ...
#  'Har du spørgsmål til løn og ansættelsesvilkår, kan du ringe til Forsvarsministeriets Personalestyrelse, HR-konsulent kaptajn Glen Spangenberg Rasmussen på telefon 32 66 53 61',
#  'Ansøgningsfrist er 18. februar 2024, hvorefter ansættelsessamtaler forventes afholdt.',
#  'Stillingen er til besættelse den 1. april 2024 eller hurtigst muligt herefter.',
#  'Hvis du vil vide mere om stillingen, er du meget velkommen til at kontakte chef for 1. Panserinfanterikompagni, kaptajn Philip Top Marchant på telefon 25 55 13 73 eller på mail GHR-1B-100A@MIL.DK.',
#  'Har du spørgsmål til løn- og ansættelsesvilkår, kan du kontakte HR-konsulent Susan Hadberg ved Forsvarsministeriets Personalestyrelse på mail FPS-SHA@MIL.DK.',
#  'Ansøgningsfrist er 12. februar 2024 og samtaler forventes afholdt løbende.',
#  'Bliv finanselev i Arbejdernes Landsbank august 2024, men start allerede nu som kunderådgiver service.',
#  'Kunderådgiver service (i perioden fra nu og frem til august 2024)',
#  'Vi ser frem til at modtage dit CV og din ansøgning senest d. 11. februar 2024',
#  'Vi holder løbende samtaler, og hvis du vil vide mere om stillingen, er du velkommen til at kontakte Privatkundedirektør Jannie Petersen på 3848 4419 eller Privatkundechef Mads Carlsson på 3848 32914.',
#  'Læs mere på www.al-bank.dk/finanselev.',
#  'Bahne i Sønderborg søger en dygtig salgselev til boligafdelingen pr. 1. august 2024.',
#  'Skriftlig ansøgning + CV (Word/PDF – gerne med foto) mærket "BOLIGELEV - SØNDERBORG" sendes pr. mail til job@bahne.dk.',
#  'Borgen Bycenter * 6400 Sønderborg * www.bahne.dk',
#  'Se mere på www.bahne.dk.',
#  'Social- og sundhedsassistentelever til start på Grundforløb 15. april 2024',
#  'Til uddannelsesstart d. 15. april 2024.',
#  'Øvrige informationer om uddannelsen: www.zbc.dk',
#  'Du skal søge stillingen elektronisk, klik på "send ansøgning". Du skal forinden ansøgningen søge optagelse på Grundforløb 2 på www.optagelse.dk.',
#  'www.optagelse.dk inden du søger om elevplads samt vedlægge dokumentation på, at',
#  'Er du velkommen til at kontakte uddannelseskonsulent Vicki Eisø på telefon 40 33 42 21.',
#  'https://www.solrod.dk/kommunen/ledige-stillinger/elever-og-studerende/social-og-sundhedselever',
#  'Telefon 56182300',
#  'personale@solrod.dk',
#  'Social- og sundhedshjælperelev til start på Grundforløb 15. april 2024',
#  'Til uddannelsesstart den 15. april 2024, søger vi elever til Grundforløb 2.',
#  'Så er du velkommen til at kontakte Uddannelseskonsulent Vicki Eisø på telefon 40 33 42 21',
#  'Ved spørgsmål er du velkommen til at kontakte funktionsleder Rikke Aagaard på telefon 5163 4755.',
#  'Familieretshuset åbnede 1. april 2019 og erstattede Statsforvaltningen.',
#  'https://familieretshuset.dk',
#  'Stillingen er en fuldtidsstilling på 37 timer ugentligt og er med start senest den 1. april 2024.',
#  'Ansvars- og kompetencebeskrivelse for stillingen kan rekvireres på sundhed-omsorg@struer.dk',
#  'Eventuelle spørgsmål vedrørende stillingen besvares ved henvendelse til leder af Udvikling og Administration Dorthe Høy på 22 13 23 93, eller funktionsleder for Enggård Centret Anni Skov Kristensen på 20 67 28 58.',
#  'Vi forventer at holde samtaler den 22. februar.',
#  'Kontakt Tilflytterservice på tilflytterservice@struer.dk eller 96 84 87 94.',
#  'Du er også velkommen til at søge inspiration på www.flyttilstruer.dk',
#  'Vil du vide mere om jobbet i Kernehuset, så kontakt pædagogisk teamleder Henriette Olesen på tlf. 30639281. Du må også meget gerne komme på besøg – bare ring, så finder vi en dag.',
#  'Telefon: +4530639281',
#  'Telefon 62 23 30 00',
#  'Tiltrædelse: 1. april 2024 eller snarest derfter',
#  'Telefon: 29 24 20 25',
#  'Til ansættelse i OUH, Rengøring og Hospitalsservice opslås hermed 5 stillinger som rengøringsassistent pr. den 1. april 2024',
#  'kan du henvende dig til serviceleder Wiebke S Jørgensen på 29 24 02 86 Indenfor tidsrummet kl. 10-11 på hverdage.',
#  'Har du lyst til at høre mere om stillingen, er du velkommen til at kontakte serviceleder Søren Uldall Beck på tlf. 21 79 92 98.',
#  'https://sonderborgkommune.dk',
#  'http://sonderborg.dk/da/tilflytter',
#  'Telefon: 72597997',
#  'Tiltrædelse: 1. april eller snarest muligt',
#  'Tlf. 7259 6000',
#  'Der er tale om en tidsbegrænset ansættelse frem til 31. juli 2026 med mulighed for forlængelse.',
#  'Pr. 1. august 2024',
#  'Ansøgningsfristen er tirsdag den 20. februar 2024. Vi forventer at afholde samtaler i uge 9. Du søger under "Job" på www.um.dk . Du skal indsende en målrettet og motiveret ansøgning på maksimum 1 side og et CV indeholdende oplysninger om uddannelse, ...',
#  'Skulle du have spørgsmål til stillingen, som ikke er besvaret i opslaget eller kan findes på www.um.dk , er du meget velkommen til at kontakte chefkonsulent i Udenrigsministeriet Joan Hentze joahen@um.dk , +45 33 92 00 00 og chefkonsulent, Lægemidler ...',
#  'Du kan læse om the Trade Council på www.tradecouncil.dk.',
#  'Alle ledige stillinger i Udenrigsministeriet kan findes på www.um.dk .',
#  'Vil du høre mere, om et spændende og udfordrende job som dagplejer i ovenstående områder, er du velkommen til at kontakte dagplejepædagog Christina Wernblad på tlf.: 79 94 70 03 eller dagplejepædagog Malene H. Hansen på tlf.: 79 94 70 02.',
#  'Din ansøgning skal være Dagplejen Varde i hænde senest den 18. februar 2024.',
#  'Gå på opdagelse i alt det, Varde Kommune har at tilbyde dig og din familie på www.flyttilvarde.dk',
#  'Telefon: +4579947003',
#  'Tlf. 79 94 68 00',
#  'Email: vardekommune@varde.dk',
#  'Stillingen er til besættelse snarest muligt eller senest den 1. april 2024',
#  'For yderligere oplysninger, er du velkommen til at kontakte Teamleder Nicolina Gjógvará på tlf. 2051 9727, e-mail ngjg@varde.dk',
#  'Telefon: +4520519727',
#  'Stillingen er til besættelse snarest muligt eller senest den 1. april 2024.',
#  'Ansøgningsfrist d. 18. februar 2024.',
#  'Yderligere oplysninger: Har du spørgsmål vedrørende stillingen, er du velkommen til at kontakte Udviklingschef Kasper Bech Pedersen (2035 4264) eller Erhvervskonsulent Nikolaj Chelander Knudsen (2944 5029).',
#  'Telefon: 20354264',
#  'Den forventede opstart er den 1. august 2024 eller snarest muligt derefter.',
#  'Vil du vide mere om Vejdirektoratet, og hvad det vil sige at arbejde hos os, kan du læse mere om vores opgaver og medarbejdere på www.vejdirektoratet.dk.',
#  'Hvis du vil vide mere om stillingen, er du velkommen til at kontakte teamleder Katrine Søborg Høyer på +45 61930439 og/eller kasho@vd.dk.',
#  'Vi opfordrer dig til at søge stillingen snarest og senest d. 5. maj, da vi ansætter praktikanter løbende.',
#  'Søg stillingen ved at trykke på linket "Søg stillingen" eller via vores hjemmeside www.vejdirektoratet.dk.',
#  'https://www.vejdirektoratet.dk',
#  'Du kan høre nærmere om stillingen ved personale- og pædagogfaglig leder Betina Petersen: tlf. 2965 0026',
#  'Ansøgningsfrist er den 18. februar 2024.',
#  'Ansættelsessamtaler forventes afholdt den 23. februar 2024.',
#  'Telefon: +45 79 96 50 00',
#  'Fra februar 2024.',
#  'Yderlige oplysninger kan fås hos leder Dorte Them mobil 22 29 35 15.',
#  'Frist: 16. februar 2024',
#  'Telefon 55 36 36 36',
#  'CVR: 29 18 96 76',
#  'Rengøringsassistent til Kastaniegården og Sundhedscenter Phønix, pr. 1. marts 2024',
#  'Yderligere oplysninger om stillingen kan fås ved henvendelse til tilsynsassistent Dorthe Colding tlf. 40 28 11 87',
#  'Opstart: Fredag den 1. marts 2024 eller snarest derefter',
#  'Ansøgningsfrist: Tirsdag den 13. februar 2024',
#  'Telefonnummer: 40281187',
#  'Tiltrædelse: 1. marts 2024',
#  'Tlf: +45 98 45 50 00',
#  '29189498',
#  'Du kan også kontakte butikschef Mikael Aagaard på mail: butik.433@coop365.dk eller kigge forbi butikken og få en snak.',
#  'Ansøg via "Ansøg nu" senest den 25. februar 2024.',
#  'Læs mere om dine muligheder som elev hos REMA 1000 på vores hjemmeside her https://job.rema1000.dk/karriere-i-butik/elev',
#  'http://rema1000.dk',
#  'https://www.jobindex.dk/jobannonce/reportage/1801/bliv-hverdagens-helt-bliv-sanitoer-med-fokus-paa-rengoering-hos-recover-vejle',
#  'Har du ikke mulighed for at starte uddannelsen pr. 1. april 2024 vil det også være muligt at vente til 1. august 2024.',
#  'Ønsker du at læse stilling- og funktionsbeskrivelsen eller har andre spørgsmål til stillingen, og er du meget velkommen til at kontakte klinisk uddannelsesansvarlig Mette Skriver på tlf. 35459879 eller mail mette.skriver@regionh.dk .',
#  'Ansøgning og CV sendes online via linket her på siden, og skal være os i hænde senest 12. februar 2024, kl. 12.00.',
#  'Hvis du vil vide mere om afdelingen eller komme forbi til en kop kaffe for at mærke stemningen, er du velkommen til at ringe ind og tale med sygeplejerske My på 35454042.',
#  'Vil du vide mere om stillingen, kan du kontakte oversygeplejerske Katrine Strini Zachhau, katrine.strini.zachhau@regionh.dk, tlf. 35455943.',
#  'Ønsker du yderligere oplysninger, er du velkommen til at kontakte Funktionsleder Christian Cook tlf.: 61359809.',
#  'Ansøgning via HR-Manager skal være os i hænde senest fredag den 23. februar.',
#  'Du kan kontakte stabschef Palle Jørgensen på tlf. 29 29 08 93',
#  'Ansøgning skal være modtaget senest søndag den 18. februar.',
#  'Samtaler planlægges afholdt onsdag den 21. februar med evt. 2. samtale mandag den 26. februar.',
#  'For yderligere information henvises til afdelingens hjemmeside: https://www.rigshospitalet.dk/afdelinger-og-klinikker/hovedorto/klinik-for-ergo-og-fysioterapi/Sider/default.aspx',
#  'Ring gerne for at høre mere om stillingen hos overergoterapeut Lisette Dolling på tlf 38633210.',
#  'Ansøgningsfrist søndag d. 10. marts 2024',
#  'Yderligere oplysninger om stillingen kan fås ved henvendelse til Grethe Juhl på telefon 29607748',
#  'TLF. 89 40 20 00',
#  'CVR-nummer: 55133018',
#  'Ansøgningsfrist: 29. februar 2024. Vi kalder løbende til samtale og fjerner opslaget når rette kandidat er fundet.',
#  'Vil du vide mere om stillingen, er du velkommen til at kontakte centerchef Susanne Peyk på tlf. 2055 3945 eller økonomispecialiste Annemarie Kortbæk-Sandal på tlf. 2143 4532.',
#  'Ansøgningsfrist: Den 19.februar 2024',
#  'Ansættelsessamtaler: Afholdes den 21.februar 2024',
#  'Tiltrædelse: Den 1.april 2024',
#  'Du er velkommen til at kontakte Brian Christensen (Teamleder) på tlf.: 20758616, hvis du vil vide mere om stillingen.',
#  "Brug linket 'Søg jobbet' for at søge stillingen eller søg via www.horsholm.dk/job . Du vil blive bedt om kontaktoplysninger og om at uploade CV og ansøgning.",
#  'http://www.horsholm.dk',
#  'Alternativt kan formand Joachim Pedersen kontaktes på tlf. 30 46 87 56 eller mail jope@munck.dk',
#  '2. februar 2024',
#  'Du kan læse mere om Grønlands Selvstyre på http://www.naalakkersuisut.gl/job',
#  'Tiltrædelsesdato: 1. marts 2024 eller efter nærmere aftale.',
#  'Namminersorlutik Oqartussat | Imaneq 4, Postboks 1015 | 3900 Nuuk | Telefon (+299) 34 50 00 | E-mail stillinger@nanoq.gl',
#  'www.naalakkersuisut.gl | Facebook | LinkedIn',
#  '2. februar 2024 12:00',
#  '+299 36 22 31',
#  'Løn- og ansættelsesvilkår fastsættes i henhold til regulativ for Museums-og Oplevelsesformidlere af 14. januar 2022.',
#  'Du skal forvente, at der vil være oplæring i løbet af marts 2024.',
#  'Vi glæder os til at læse din ansøgning, som skal sendes via vores elektroniske rekrutteringssystem på Nationalmuseets hjemmeside www.natmus.dk/job og skal være museet i hænde senest mandag den 19. februar 2024.',
#  'Vi forventer at holde ansættelsessamtaler den 23. og 26. februar 2024.',
#  'Ved yderligere spørgsmål kan du kontakte booker Youssef Mohammad på telefon 4120 6704 eller oplevelses- og læringsdesigner Nanna Amalie Dahl på telefon 4120 6538.',
#  'Se mere om Nationalmuseet på www.natmus.dk',
#  'Stillingerne er ledig til besættelse pr. 1. april 2024.',
#  'Din ansøgning med CV og eksamensbevis for både bachelor- og kandidatuddannelse skal være modtaget senest 19. februar 2024. Samtaler forventes afholdt i uge 8. Der kan indgå tests i forbindelse med rekrutteringen.',
#  'Vil du vide mere om stillingen, er du meget velkommen til at kontakte chefjurist Dario Silic på telefon 72 18 58 14, mail darsil@fiskeristyrelsen.dk .',
#  'Du kan læse om Fiskeristyrelsen på www.fiskeristyrelsen.dk .',
#  'https://fiskeristyrelsen.dk/',
#  'Der er brug for dig pr. 1. april 2024.',
#  'Vi glæder os til at modtage din ansøgning sammen med CV, kopi af eksamensbevis og eventuelt andre relevante bilag via vores rekrutteringssystem på fvm.dk/job senest fredag den 16. februar 2024.',
#  'Du er velkommen til at kontakte fødevarechef Jørgen Andersen på 72 27 52 57 eller sektionsleder Søren Thomsen på 72 27 59 39, hvis du gerne vil vide mere om stillingen.',
#  'Læs mere om Fødevarestyrelsen på www.fvst.dk',
#  'http://www.fvst.dk',
#  'I januar 2021 blev Nordfyns Kommune udvalgt til at bidrage til Social- og Boligstyrelsens satspuljeprojekt "Styrket match mellem barn og anbringelsessted". Omdrejningspunktet for projektet er at understøtte udviklingen af en socialfaglig model, som ...',
#  'Som matchkonsulent vil du få en central rolle både i projektet med at implementere de nye tiltag samt det videre udviklingsarbejde med at styrke fagligheden omkring matchningsprocesser efter projektet afslutning i december 2024. Da rollen som ...',
#  'Da vores nye afdelingsleder for Familieafdelingen starter 1. februar 2024, kan du ved spørgsmål til stillingen rette henvendelse til chef for Børn og Familie Jesper Due Pedersen på tlf. 20 58 77 17.',
#  'Stillingen ønskes besat den 1. april 2024.',
#  'Vi ser frem til at modtage din ansøgning vedhæftet CV og andre relevante dokumenter senest søndag den 18. februar 2024.',
#  'Første runde ansættelsessamtaler forventes afholdt den torsdag den 22. februar 2024.',
#  'Anden runde forventes afholdt den mandag den 26. februar 2024.',
#  'Du kan læse mere om Nordfyns Kommune på vores hjemmeside www.nordfynskommune.dk.',
#  'Samtaledato: 22. februar 2024',
#  'Ansættelsesdato: 1. april 2024',
#  'CVR.nr.: 29 18 89 47',
#  'Nordfyns Kommune søger 1 sæsonmedarbejder, til Vej og Park i perioden den 1. april 2024 (eller efter nærmere aftale) til 31.10. 2024. Stillingen er på 37 timer ugentlig.',
#  'Yderligere oplysninger om stillingen kan fås ved henvendelse til leder af Vej og Park Inge Haakonsdatter på tlf. 20 58 04 21 eller grøn formand Keld Olsen tlf. 23 71 80 73.',
#  'Vi ser frem til at modtage din ansøgning vedhæftet relevante bilag, senest søndag den 18. februar 2024.',
#  'Hjemmeside: https://nordstern.dk/',
#  'Kontakt afdelingsleder i Udsigten, Louise Tolver Schmidt på telefon 5155 8861',
#  'Tiltrædelse d 1. april 2024 eller efter aftale.',
#  'Vil du gerne høre mere, har du nogle afklarende spørgsmål, eller har du lyst til at besøge Tingager, er du meget velkommen til at kontaktet Plejehjemsleder Hanne Arendt på 7253 3289, eller sygeplejerske Nanna Corydon på 7253 8290.',
#  'Vi ser frem til at modtage din ansøgning med relevante bilag senest d 19. februar 2024.',
#  'Ansættelsessamtaler afholdes tirsdag d 29. februar 2024. På Tingager plejehjem.',
#  'Frist: 19. februar 2024, 08:00',
#  'Lige nu søger vi en psykolog til et barselsvikariat på et år fra den 1. april 2024.',
#  'Der er tale om et vikariat på et år med tiltrædelse den 1. april 2024. Stillingen er på 37 timer ugentlig.',
#  'Yderligere oplysninger kan fås ved henvendelse tilover sygeplejerske Birgitte Vejstrup på 2210 1197.',
#  'Søg stillingen via link på siden senest den 18. februar 2024',
#  'Ansættelsessamtaler forventes afholdt den 21. februar 2024',
#  'Har du brug for yderligere oplysninger er du velkommen til at kontakte oversygeplejerske Trine Jessen på mail: trine.jessen@rsyd.dk eller telefon 24989264/99448250',
#  'Ansøgningsfristen er 16. februar 2024 , men vi indkalder til samtale løbende, så vent ikke for længe med at søge .',
#  'Har du brug for yderligere oplysninger, er du velkommen til at kontakte oversygeplejerske Trine Jessen på mail: trine.jessen@rsyd.dk eller telefon 24989264/994448250.',
#  'Der afholdes samtaler d. 13.februar.',
#  ...]

# %%
# remove high risk sentences
filtered_df = filtered_df[~filtered_df['sentence'].str.contains(has_risk, regex=True, flags=re.IGNORECASE)]

# init new column for cleaning
filtered_df['cleaned'] = filtered_df['sentence'].copy()

# raw clean url, email, phone and date from filtered
filtered_df['cleaned'] = filtered_df['cleaned'].str.replace(r'\W*' + has_url + r'\W*', ' ', regex=True, flags=re.IGNORECASE)
filtered_df['cleaned'] = filtered_df['cleaned'].str.replace(r'\W*' + has_email + r'\W*', ' ', regex=True, flags=re.IGNORECASE)
filtered_df['cleaned'] = filtered_df['cleaned'].str.replace(r'\W*' + has_phone + r'\W*', ' ', regex=True, flags=re.IGNORECASE)
filtered_df['cleaned'] = filtered_df['cleaned'].str.replace(r'\W*' + has_date_1 + r'\W*', ' ', regex=True, flags=re.IGNORECASE)
filtered_df['cleaned'] = filtered_df['cleaned'].str.replace(r'\W*' + has_date_2 + r'\W*', ' ', regex=True, flags=re.IGNORECASE)

# clean spaces
filtered_df['cleaned'] = filtered_df['cleaned'].str.replace(r'\s+', ' ', regex=True, flags=re.IGNORECASE).str.strip()

# seed the selection
np.random.seed(7)

# randomly select either original (10%) or cleaned (90%)
filtered_df['sentence'] = np.where(np.random.rand(len(filtered_df)) > 0.9, filtered_df['sentence'], filtered_df['cleaned'])
filtered_df.drop('cleaned', axis=1, inplace=True)

# drop empty and duplicates, and drop if already in handpicked
filtered_df = filtered_df[filtered_df['sentence'].str.len() > 0]
filtered_df = filtered_df.drop_duplicates(subset='sentence')
filtered_df = filtered_df[~filtered_df['sentence'].isin(frequent_df['sentence'])]

# check
print(filtered_df.shape)
filtered_df.head(3)
# Out:
# <ipython-input-9-e65636e710ce>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['cleaned'] = filtered_df['sentence'].copy()
# (726662, 1)
#                                              sentence
# 19  Ansøgningsfrist med tiltrædelse snarest muligt...
# 22  Advokat Rasmus Haugaard mærket "advokat til fa...
# 23  Hvis du vil vide mere om stillingen, og os som...

# %%
# examine filtered - again (finally!) (use interactive table)
filtered_df.sample(20000, random_state=7)
# Out:
#                                                   sentence
# 9163516  Hvis du vil vide mere om stillingen er du velk...
# 414486   For further information about this position co...
# 6911221  Har du spørgsmål til jobbet eller Frie generel...
# 5974536          https://studerendeonline.dk/job/2068941//
# 1029034  Ansøgningen skal stiles til Kirkeministeriet, ...
# ...                                                    ...
# 8325443  Stillingen er et barselsvikariat på 80-100% me...
# 742955   Application deadline is 2 January 2024 at 23:5...
# 9120064         Ved spørgsmål, kontakt Peter Orloff på tlf
# 9177417  For yderligere information er du velkommen til...
# 5540473  Hvis du ønsker at søge denne fantastiske still...
#
# [20000 rows x 1 columns]

# %%
# load synthetic nonskills
with open(work_dir('Data', 'notskills.txt'), 'r') as file:
    lines = file.readlines()

# filter and split lines
lines = [[l.strip() for l in line.split('=')] for line in lines if line.count('=') == 1]

# check
print(len(lines))
lines[:5]
# Out:
# 1623
# [['1. Hos SuperBiler A/S har vi specialiseret os i salg af brugte luksusbiler siden 2008',
#   'At SuperCars A/S, we have specialized in selling used luxury cars since 2008'],
#  ['2. TILMELD DIG VORES NYHEDSBREV OG FÅ DE SENESTE NYHEDER OM BRUGTE BILER DIREKTE I DIN INDBAKKE',
#   'SIGN UP FOR OUR NEWSLETTER AND GET THE LATEST NEWS ABOUT USED CARS DIRECTLY IN YOUR INBOX'],
#  ['3. Søg efter job', 'Search for jobs'],
#  ['4. Vi elsker frisk kaffe og glade medarbejdere',
#   'We love fresh coffee and happy employees'],
#  ['5. Vores hovedkontor ligger i hjertet af Aarhus',
#   'Our head office is located in the heart of Aarhus']]

# %%
# create dataframe of sentences, explode pairs into 1d
synthetic_df = pd.DataFrame([l[0] for l in lines] + [l[1] for l in lines], columns=['sentence'])

# remove list prefixes, quotations and placeholders from gpt
synthetic_df['sentence'] = synthetic_df['sentence'].str.replace(r'^\s*([\>\-\*]|\d+[\.\)])\s*', '', regex=True, flags=re.IGNORECASE)
synthetic_df['sentence'] = synthetic_df['sentence'].str.replace(r'^"(.+)"$', '\1', regex=True, flags=re.IGNORECASE)
synthetic_df['sentence'] = synthetic_df['sentence'].str.replace(r'\[.*?\]', '', regex=True, flags=re.IGNORECASE)

# remove duplicates and empty
synthetic_df = synthetic_df.drop_duplicates(subset='sentence')
synthetic_df = synthetic_df[synthetic_df['sentence'].str.len() > 0].dropna()

# check
print(synthetic_df.shape)
synthetic_df.head(3)
# Out:
# (3026, 1)
#                                             sentence
# 0  Hos SuperBiler A/S har vi specialiseret os i s...
# 1  TILMELD DIG VORES NYHEDSBREV OG FÅ DE SENESTE ...
# 2                                      Søg efter job

# %%
# sample arbitrary number of filtered and merge what we have
nonskills = pd.concat([
    synthetic_df[['sentence']].assign(group=1),
    frequent_df[['sentence']].assign(group=2),
    filtered_df[['sentence']].sample(100000 - len(synthetic_df) - len(frequent_df), random_state=7).assign(group=3)
], ignore_index=True)[['group', 'sentence']]

# check
print(nonskills.shape)
nonskills.head(3)
# Out:
# (100000, 2)
#    group                                           sentence
# 0      1  Hos SuperBiler A/S har vi specialiseret os i s...
# 1      1  TILMELD DIG VORES NYHEDSBREV OG FÅ DE SENESTE ...
# 2      1                                      Søg efter job

# %%
# save!
nonskills[['group', 'sentence']].to_json(work_dir('Data', 'nonskills.json'), orient='records', lines=True, index=False)

# %%
# load for sanity check
nonskills_reloaded = pd.read_json(work_dir('Data', 'nonskills.json'), orient='records', lines=True)

# check
print(nonskills_reloaded.shape)
nonskills_reloaded.head(3)
# Out:
# (100000, 2)
#    group                                           sentence
# 0      1  Hos SuperBiler A/S har vi specialiseret os i s...
# 1      1  TILMELD DIG VORES NYHEDSBREV OG FÅ DE SENESTE ...
# 2      1                                      Søg efter job
