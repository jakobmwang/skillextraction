# %% [markdown]
# # Installation and Importing

# %%
# dependencies
import os
import re
import gc
import numpy as np
import pandas as pd
from datetime import datetime
from google.colab import drive, userdata

# file management
drive.mount("/content/drive")
WORK_DIR = "/content/drive/MyDrive/Projects/skillextraction"

# work dir shortcut function
def work_dir(*args):
    return os.path.join(WORK_DIR, *args)
# Out:
# Mounted at /content/drive

# %%
# load database export and drop na columns
jobads = pd.concat([pd.read_csv(work_dir(f'jobads{i}.csv.gz'), compression='gzip', low_memory=False) for i in range(1, 5)], ignore_index=True)
jobads = jobads.drop(columns=['id', 'url', 'category']).dropna(subset='content').reset_index(drop=True)
jobads['date'] = pd.to_datetime(jobads['published'], format='%Y-%m-%d')
jobads
# Out:
#            source                                           real_url  \
# 0        jobindex  https://www.jobindex.dk/jobannonce/502456/advo...
# 1        jobindex  https://jobs.dnv.com/job-search/business-assur...
# 2        jobindex  https://jobteam.dk/afdeling/6000U/6000U-C43/jo...
# 3        jobindex  https://www.jobindex.dk/jobannonce/r12281807/j...
# 4        jobindex  https://www.jobindex.dk/jobannonce/r12282086/e...
# ...           ...                                                ...
# 3114254  jobindex  http://www.jobindex.dk/cgi/open.cgi?rm=jobnet&...
# 3114255  jobindex  http://www.jobindex.dk/cgi/open.cgi?rm=jobnet&...
# 3114256  jobindex  http://www.peoplexs.com/Peoplexs22/CandidatesP...
# 3114257  jobindex  http://www.peoplexs.com/Peoplexs22/CandidatesP...
# 3114258  jobindex  http://www.jobworld.dk/job/9013/klinisk-it-kon...
#
#                                                      title  \
# 0        Advokat til afdeling for fast ejendom og entre...
# 1                      Key Customer Project Manager (KCPM)
# 2               Salgs- og eventkoordinator søges i Esbjerg
# 3        Jobcenter Aarhus, Job og Virksomhedsservice, C...
# 4        Er du vores nye rengøringsassistent i Sakskøbing?
# ...                                                    ...
# 3114254                                 Rustfast klejnsmed
# 3114255                                                Kok
# 3114256                        Akutjob: Salgsleder i Netto
# 3114257        Butiksassistent deltid, Netto - under 18 år
# 3114258                               Klinisk IT-konsulent
#
#                                       company           location  \
# 0        Haugaard Braad Advokatpartnerselskab            Aalborg
# 1          Dnv Business Assurance Denmark A/S           Hellerup
# 2                                         NaN            Esbjerg
# 3                              Aarhus Kommune           Aarhus C
# 4                                         NaN         Sakskøbing
# ...                                       ...                ...
# 3114254                                   NaN            Kolding
# 3114255                                   NaN          Holstebro
# 3114256                                 Netto          Hirtshals
# 3114257                                 Netto  Vallensbæk Strand
# 3114258                    Region Midtjylland              Valby
#
#                                                    content   published  \
# 0        Advokat til afdeling for fast ejendom og entre...  2024-02-07
# 1        Key Customer Project Manager (KCPM)\nLocation:...  2024-02-07
# 2        Jobsøgende Industri og Lager Kolding Industri ...  2024-02-07
# 3        Jobcenter Aarhus, Job og Virksomhedsservice, C...  2024-02-07
# 4        Er du vores nye rengøringsassistent i Sakskøbi...  2024-02-07
# ...                                                    ...         ...
# 3114254  Lignende jobannoncer\n• Job i Sydjylland kateg...  2012-11-23
# 3114255  Lignende jobannoncer\n• Job i Region Midtjylla...  2012-11-23
# 3114256  Akutjob: Salgsleder i Netto\nSådan er vi\nTage...  2012-11-23
# 3114257  Butiksassistent deltid, Netto - under 18 år\nV...  2012-11-23
# 3114258  Danmarks største it-jobsite\nFlere søgemulighe...  2012-11-22
#
#                      crawled       date
# 0        2024-02-09 11:56:34 2024-02-07
# 1        2024-02-09 11:56:35 2024-02-07
# 2        2024-02-09 11:56:35 2024-02-07
# 3        2024-02-09 11:56:36 2024-02-07
# 4        2024-02-09 11:56:36 2024-02-07
# ...                      ...        ...
# 3114254  2024-12-21 08:21:06 2012-11-23
# 3114255  2024-12-21 08:21:06 2012-11-23
# 3114256  2024-12-21 08:21:06 2012-11-23
# 3114257  2024-12-21 08:21:06 2012-11-23
# 3114258  2024-12-21 08:43:46 2012-11-22
#
# [3114259 rows x 9 columns]

# %%
# extract domains excluding www.
domain = jobads['real_url'].str.extract(r'^https?:\/\/(?:www\.)?([^\/]+)\/?.*$')

# check
domain.value_counts()
# Out:
# 0
# jobindex.dk                 1375220
# candidate.hr-manager.net     251302
# jobzonen.dk                  130245
# jobsincopenhagen.com          44432
# sallinggroup.com              38775
#                              ...
# friis-ren.dk                      1
# perform.dk                        1
# friluftsland.dk                   1
# frilundbiler.dk                   1
# 100plus.dk                        1
# Name: count, Length: 14223, dtype: int64

# %%
# check sdu ad counts
jobads[jobads['company'] == 'Syddansk Universitet'].dropna()['date'].dt.year.value_counts().sort_index()
# Out:
# date
# 2012     56
# 2013    700
# 2014    636
# 2015    669
# 2016    526
# 2017    691
# 2018    846
# 2019    813
# 2020    766
# 2021    516
# 2022    676
# 2023    595
# 2024     31
# Name: count, dtype: int64

# %%
# isolate an sdu decade
sdu = jobads[(jobads['company'] == 'Syddansk Universitet') &
             (jobads['date'].dt.year > 2013) &
             (jobads['date'].dt.year < 2024)].dropna().reset_index(drop=True)

# check
sdu['date'].dt.year.value_counts().sort_index()
# Out:
# date
# 2014    636
# 2015    669
# 2016    526
# 2017    691
# 2018    846
# 2019    813
# 2020    766
# 2021    516
# 2022    676
# 2023    595
# Name: count, dtype: int64
